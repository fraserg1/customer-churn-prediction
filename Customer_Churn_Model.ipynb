# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#CHURN-MODEL" data-toc-modified-id="CHURN-MODEL-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>CHURN MODEL</a></span><ul class="toc-item"><li><span><a href="#Import-Modules" data-toc-modified-id="Import-Modules-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import Modules</a></span></li><li><span><a href="#Feature-Gathering" data-toc-modified-id="Feature-Gathering-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Feature Gathering</a></span><ul class="toc-item"><li><span><a href="#Transactional-Data" data-toc-modified-id="Transactional-Data-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Transactional Data</a></span><ul class="toc-item"><li><span><a href="#Data-Importing" data-toc-modified-id="Data-Importing-1.2.1.1"><span class="toc-item-num">1.2.1.1&nbsp;&nbsp;</span>Data Importing</a></span></li><li><span><a href="#Data-Exploration" data-toc-modified-id="Data-Exploration-1.2.1.2"><span class="toc-item-num">1.2.1.2&nbsp;&nbsp;</span>Data Exploration</a></span></li><li><span><a href="#Data-Transformation" data-toc-modified-id="Data-Transformation-1.2.1.3"><span class="toc-item-num">1.2.1.3&nbsp;&nbsp;</span>Data Transformation</a></span></li></ul></li><li><span><a href="#RFM-Analysis" data-toc-modified-id="RFM-Analysis-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>RFM Analysis</a></span><ul class="toc-item"><li><span><a href="#RFM-Data-Transformation" data-toc-modified-id="RFM-Data-Transformation-1.2.2.1"><span class="toc-item-num">1.2.2.1&nbsp;&nbsp;</span>RFM Data Transformation</a></span></li><li><span><a href="#RFM-Scoring" data-toc-modified-id="RFM-Scoring-1.2.2.2"><span class="toc-item-num">1.2.2.2&nbsp;&nbsp;</span>RFM Scoring</a></span></li><li><span><a href="#RFM-Segmentation" data-toc-modified-id="RFM-Segmentation-1.2.2.3"><span class="toc-item-num">1.2.2.3&nbsp;&nbsp;</span>RFM Segmentation</a></span></li></ul></li><li><span><a href="#K-Means-Clustering-with-RFM" data-toc-modified-id="K-Means-Clustering-with-RFM-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>K-Means Clustering with RFM</a></span><ul class="toc-item"><li><span><a href="#Hopkins-Statistics:" data-toc-modified-id="Hopkins-Statistics:-1.2.3.1"><span class="toc-item-num">1.2.3.1&nbsp;&nbsp;</span>Hopkins Statistics:</a></span></li><li><span><a href="#K-Means-with-some-K" data-toc-modified-id="K-Means-with-some-K-1.2.3.2"><span class="toc-item-num">1.2.3.2&nbsp;&nbsp;</span>K-Means with some K</a></span></li><li><span><a href="#Silhouette-Analysis" data-toc-modified-id="Silhouette-Analysis-1.2.3.3"><span class="toc-item-num">1.2.3.3&nbsp;&nbsp;</span>Silhouette Analysis</a></span></li><li><span><a href="#Sum-of-Squared-Sums-(Elbow-Plot)" data-toc-modified-id="Sum-of-Squared-Sums-(Elbow-Plot)-1.2.3.4"><span class="toc-item-num">1.2.3.4&nbsp;&nbsp;</span>Sum of Squared Sums (Elbow Plot)</a></span></li><li><span><a href="#RFM-Cluster-Analysis" data-toc-modified-id="RFM-Cluster-Analysis-1.2.3.5"><span class="toc-item-num">1.2.3.5&nbsp;&nbsp;</span>RFM Cluster Analysis</a></span></li></ul></li><li><span><a href="#Tenure-and-Churning" data-toc-modified-id="Tenure-and-Churning-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Tenure and Churning</a></span></li><li><span><a href="#Demographic-Data" data-toc-modified-id="Demographic-Data-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>Demographic Data</a></span><ul class="toc-item"><li><span><a href="#Data-Importing" data-toc-modified-id="Data-Importing-1.2.5.1"><span class="toc-item-num">1.2.5.1&nbsp;&nbsp;</span>Data Importing</a></span></li><li><span><a href="#Data-Exploration" data-toc-modified-id="Data-Exploration-1.2.5.2"><span class="toc-item-num">1.2.5.2&nbsp;&nbsp;</span>Data Exploration</a></span></li><li><span><a href="#Data-Transformation" data-toc-modified-id="Data-Transformation-1.2.5.3"><span class="toc-item-num">1.2.5.3&nbsp;&nbsp;</span>Data Transformation</a></span></li></ul></li><li><span><a href="#Attitudinal-Data" data-toc-modified-id="Attitudinal-Data-1.2.6"><span class="toc-item-num">1.2.6&nbsp;&nbsp;</span>Attitudinal Data</a></span><ul class="toc-item"><li><span><a href="#Data-Importing" data-toc-modified-id="Data-Importing-1.2.6.1"><span class="toc-item-num">1.2.6.1&nbsp;&nbsp;</span>Data Importing</a></span></li><li><span><a href="#Data-Exploration" data-toc-modified-id="Data-Exploration-1.2.6.2"><span class="toc-item-num">1.2.6.2&nbsp;&nbsp;</span>Data Exploration</a></span></li><li><span><a href="#Data-Transformation" data-toc-modified-id="Data-Transformation-1.2.6.3"><span class="toc-item-num">1.2.6.3&nbsp;&nbsp;</span>Data Transformation</a></span></li></ul></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Creating-Historical-and-Live-Data-(For-Model-and-Scoring)" data-toc-modified-id="Creating-Historical-and-Live-Data-(For-Model-and-Scoring)-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Creating Historical and Live Data (For Model and Scoring)</a></span></li><li><span><a href="#Missing-and-Inconsistent-Data" data-toc-modified-id="Missing-and-Inconsistent-Data-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Missing and Inconsistent Data</a></span></li><li><span><a href="#Categorical-Data" data-toc-modified-id="Categorical-Data-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Categorical Data</a></span></li><li><span><a href="#Continuous-Data" data-toc-modified-id="Continuous-Data-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Continuous Data</a></span></li></ul></li><li><span><a href="#Feature-Selection" data-toc-modified-id="Feature-Selection-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Feature Selection</a></span><ul class="toc-item"><li><span><a href="#Feature-Voting" data-toc-modified-id="Feature-Voting-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Feature Voting</a></span></li><li><span><a href="#Multicollinearity" data-toc-modified-id="Multicollinearity-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Multicollinearity</a></span><ul class="toc-item"><li><span><a href="#VIF---Variable-Inflation-Factors" data-toc-modified-id="VIF---Variable-Inflation-Factors-1.4.2.1"><span class="toc-item-num">1.4.2.1&nbsp;&nbsp;</span>VIF - Variable Inflation Factors</a></span></li></ul></li><li><span><a href="#Extra---Chi2-dependancy-check" data-toc-modified-id="Extra---Chi2-dependancy-check-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Extra - Chi2 dependancy check</a></span></li></ul></li><li><span><a href="#Model-Selection" data-toc-modified-id="Model-Selection-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Model Selection</a></span><ul class="toc-item"><li><span><a href="#Test/Training-Set" data-toc-modified-id="Test/Training-Set-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Test/Training Set</a></span></li><li><span><a href="#Model-Algorithms" data-toc-modified-id="Model-Algorithms-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Model Algorithms</a></span></li><li><span><a href="#Hyperparameter-Tuning" data-toc-modified-id="Hyperparameter-Tuning-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Hyperparameter Tuning</a></span><ul class="toc-item"><li><span><a href="#Validation-curves" data-toc-modified-id="Validation-curves-1.5.3.1"><span class="toc-item-num">1.5.3.1&nbsp;&nbsp;</span>Validation curves</a></span></li><li><span><a href="#Grid-Search-Cross-Validation" data-toc-modified-id="Grid-Search-Cross-Validation-1.5.3.2"><span class="toc-item-num">1.5.3.2&nbsp;&nbsp;</span>Grid Search Cross Validation</a></span></li></ul></li></ul></li><li><span><a href="#Evaluating-the-Model" data-toc-modified-id="Evaluating-the-Model-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Evaluating the Model</a></span><ul class="toc-item"><li><span><a href="#Classification-Report" data-toc-modified-id="Classification-Report-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Classification Report</a></span></li></ul></li><li><span><a href="#A/B-testing" data-toc-modified-id="A/B-testing-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>A/B testing</a></span><ul class="toc-item"><li><span><a href="#Maximum-Return" data-toc-modified-id="Maximum-Return-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>Maximum Return</a></span></li></ul></li><li><span><a href="#Data-Scoring" data-toc-modified-id="Data-Scoring-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Data Scoring</a></span><ul class="toc-item"><li><span><a href="#Data-preparation" data-toc-modified-id="Data-preparation-1.8.1"><span class="toc-item-num">1.8.1&nbsp;&nbsp;</span>Data preparation</a></span></li><li><span><a href="#Model-Deployment" data-toc-modified-id="Model-Deployment-1.8.2"><span class="toc-item-num">1.8.2&nbsp;&nbsp;</span>Model Deployment</a></span></li></ul></li><li><span><a href="#Customer-Profiling" data-toc-modified-id="Customer-Profiling-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Customer Profiling</a></span></li></ul></li></ul></div>

# %% [markdown]
# # CHURN MODEL

# %% [markdown]
# ## Import Modules

# %%
import pyodbc # sql libraries
import pandas as pd #dataframes
import numpy as np #Arrays
import matplotlib.pyplot as plt #graphs
plt.style.use('ggplot') #ggplots style
import seaborn as sns
from sklearn.preprocessing import RobustScaler # to scale data
from sklearn.cluster import KMeans # K means clustering
from sklearn.model_selection import train_test_split # randomly split data
# from xverse.transformer import WOE # to perform weight of evidence for feature selection
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.metrics import accuracy_score #accuracy for model assessment
from sklearn.feature_selection import RFE # Recursive Feature Elimination
from sklearn.linear_model import LogisticRegression # Logistic Regression
from sklearn.ensemble import ExtraTreesClassifier # Extra Trees
from sklearn.feature_selection import SelectKBest, chi2 # K best and Chi square
from sklearn.svm import LinearSVC # Linear SVC for feature selection
from sklearn.feature_selection import SelectFromModel # 11 feature selection
from functools import reduce #to merge dataframes
from statsmodels.stats.outliers_influence import variance_inflation_factor # Multicollinearity check
from sklearn.ensemble import GradientBoostingClassifier #Gradient Boosting
from sklearn.metrics import fbeta_score # fbeta score for model assessment
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis #LDA
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.neural_network import MLPClassifier # Neural Network
from sklearn.naive_bayes import GaussianNB # Naive Bayes
from sklearn.preprocessing import MinMaxScaler # To Scale data for SVC
from sklearn.svm import SVC # Support Vector Machine
from sklearn.model_selection import validation_curve, StratifiedKFold, GridSearchCV,RepeatedStratifiedKFold # For model Tuning
from sklearn.metrics import confusion_matrix, classification_report #For model evaluation
import joblib# to save the final model
import mlxtend as ml # Market Basket Analysis
from mlxtend.frequent_patterns import apriori # extract frequency items for MBA
from mlxtend.frequent_patterns import association_rules # create the MBA rules
from datetime import timedelta # define potential churn date
from warnings import simplefilter # warnings filter
from sklearn.tree import DecisionTreeClassifier # Decision Tree
#Ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Feature Gathering

# %% [markdown]
# ### Transactional Data

# %% [markdown]
# #### Data Importing

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=G-K-FRASER;'
                      'Database=AdventureWorksDW2017;'
                      'Trust_Connection= yes;')

# %%
Transactions= pd.read_sql_query('''
SELECT
A.[CustomerKey] AS 'Customer_ID',
A.[SalesOrderNumber] AS 'Sales Order Number',
B.[EnglishProductName] AS 'Product Name',
A.[OrderDate] AS 'Order Date',
A.[OrderQuantity]  AS 'Order Quantity',
A.[SalesAmount] AS 'Revenue',
A.[TotalProductCost] AS 'Cost',
(A.[SalesAmount]-A.[TotalProductCost]) AS 'Profit'
FROM
[dbo].[FactInternetSales] AS A
LEFT JOIN [dbo].[DimProduct] AS B
ON A.[ProductKey] = B.[ProductKey]

''', conn)

#close connection
#conn.close()

# %% [markdown]
# #### Data Exploration

# %%
Transactions.head()
# Out:
#    Customer_ID Sales Order Number             Product Name Order Date  \
# 0        21768            SO43697         Road-150 Red, 62 2010-12-29
# 1        28389            SO43698  Mountain-100 Silver, 44 2010-12-29
# 2        25863            SO43699  Mountain-100 Silver, 44 2010-12-29
# 3        14501            SO43700       Road-650 Black, 62 2010-12-29
# 4        11003            SO43701  Mountain-100 Silver, 44 2010-12-29
#
#    Order Quantity    Revenue       Cost     Profit
# 0               1  3578.2700  2171.2942  1406.9758
# 1               1  3399.9900  1912.1544  1487.8356
# 2               1  3399.9900  1912.1544  1487.8356
# 3               1   699.0982   413.1463   285.9519
# 4               1  3399.9900  1912.1544  1487.8356

# %%
Transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60398 entries, 0 to 60397
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         60398 non-null  int64
#  1   Sales Order Number  60398 non-null  object
#  2   Product Name        60398 non-null  object
#  3   Order Date          60398 non-null  datetime64[ns]
#  4   Order Quantity      60398 non-null  int64
#  5   Revenue             60398 non-null  float64
#  6   Cost                60398 non-null  float64
#  7   Profit              60398 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(2)
# memory usage: 3.7+ MB

# %% [markdown]
# #### Data Transformation

# %%
# convert quantity into float as it is more useful for ML modeling later on

Transactions['Order Quantity'] = Transactions['Order Quantity'].astype(float)

# %%
# check for duplicate rows
duplicate_rows = Transactions.duplicated().sum()
print('Number of duplicate rows =', duplicate_rows)
# Out:
# Number of duplicate rows = 0

# %%
#aggregate the data per transaction
transaction_df = Transactions.groupby(['Customer_ID', 'Sales Order Number', 'Order Date']).agg({'Order Quantity':sum,
                                                                                        'Revenue':sum,
                                                                                        'Profit' :sum}).reset_index()
transaction_df.head()
# Out:
#    Customer_ID Sales Order Number Order Date  Order Quantity  Revenue  \
# 0        11000            SO43793 2011-01-19             1.0  3399.99
# 1        11000            SO51522 2013-01-18             2.0  2341.97
# 2        11000            SO57418 2013-05-03             5.0  2507.03
# 3        11001            SO43767 2011-01-15             1.0  3374.99
# 4        11001            SO51493 2013-01-16             6.0  2419.93
#
#       Profit
# 0  1487.8356
# 1  1068.1300
# 2   957.7249
# 3  1476.8956
# 4  1091.9928

# %%
# Elapsed Period between transactions per customer

transaction_df['Days Elapsed'] = transaction_df.groupby('Customer_ID')['Order Date'].diff()
transaction_df['Days Elapsed'] = transaction_df['Days Elapsed'] / np.timedelta64(1, 'D')

transaction_df.head()
# Out:
#    Customer_ID Sales Order Number Order Date  Order Quantity  Revenue  \
# 0        11000            SO43793 2011-01-19             1.0  3399.99
# 1        11000            SO51522 2013-01-18             2.0  2341.97
# 2        11000            SO57418 2013-05-03             5.0  2507.03
# 3        11001            SO43767 2011-01-15             1.0  3374.99
# 4        11001            SO51493 2013-01-16             6.0  2419.93
#
#       Profit  Days Elapsed
# 0  1487.8356           NaN
# 1  1068.1300         730.0
# 2   957.7249         105.0
# 3  1476.8956           NaN
# 4  1091.9928         732.0

# %%
# Aggregate data per customer

agg = ['sum', 'mean', 'median', 'min', 'max']
transaction_per_cust = transaction_df.groupby('Customer_ID').agg({'Order Quantity': agg, 'Revenue':agg,
                                                                 'Profit':agg, 'Days Elapsed':agg}).reset_index()

transaction_per_cust.head()
# Out:
#   Customer_ID Order Quantity                             Revenue               \
#                          sum      mean median  min  max      sum         mean
# 0       11000            8.0  2.666667    2.0  1.0  5.0  8248.99  2749.663333
# 1       11001           11.0  3.666667    4.0  1.0  6.0  6383.88  2127.960000
# 2       11002            4.0  1.333333    1.0  1.0  2.0  8114.04  2704.680000
# 3       11003            9.0  3.000000    4.0  1.0  4.0  8139.29  2713.096667
# 4       11004            6.0  2.000000    2.0  1.0  3.0  8196.01  2732.003333
#
#                      ...     Profit                                    \
#     median      min  ...        sum         mean     median       min
# 0  2507.03  2341.97  ...  3513.6905  1171.230167  1068.1300  957.7249
# 1  2419.93   588.96  ...  2795.8839   931.961300  1091.9928  226.9955
# 2  2419.06  2294.99  ...  3454.8801  1151.626700  1043.0087  924.0358
# 3  2420.34  2318.96  ...  3467.1264  1155.708800  1054.4538  924.8370
# ...

# %%
# flatten coumns except for Customer_ID

trans = transaction_per_cust.drop('Customer_ID', axis = 1)
trans.columns = ["_".join(trans) for trans in trans.columns.ravel()]

trans.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:3936: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    Order Quantity_sum  Order Quantity_mean  Order Quantity_median  \
# 0                 8.0             2.666667                    2.0
# 1                11.0             3.666667                    4.0
# 2                 4.0             1.333333                    1.0
# 3                 9.0             3.000000                    4.0
# 4                 6.0             2.000000                    2.0
#
#    Order Quantity_min  Order Quantity_max  Revenue_sum  Revenue_mean  \
# 0                 1.0                 5.0      8248.99   2749.663333
# 1                 1.0                 6.0      6383.88   2127.960000
# 2                 1.0                 2.0      8114.04   2704.680000
# ...

# %%
# Add back Customer_ID column

trans.insert(0, 'Customer_ID', transaction_per_cust['Customer_ID'])

trans.head()
# Out:
#    Customer_ID  Order Quantity_sum  Order Quantity_mean  \
# 0        11000                 8.0             2.666667
# 1        11001                11.0             3.666667
# 2        11002                 4.0             1.333333
# 3        11003                 9.0             3.000000
# 4        11004                 6.0             2.000000
#
#    Order Quantity_median  Order Quantity_min  Order Quantity_max  Revenue_sum  \
# 0                    2.0                 1.0                 5.0      8248.99
# 1                    4.0                 1.0                 6.0      6383.88
# 2                    1.0                 1.0                 2.0      8114.04
# 3                    4.0                 1.0                 4.0      8139.29
# 4                    2.0                 1.0                 3.0      8196.01
#
#    Revenue_mean  Revenue_median  Revenue_min  ...  Profit_sum  Profit_mean  \
# 0   2749.663333         2507.03      2341.97  ...   3513.6905  1171.230167
# ...

# %% [markdown]
# ### RFM Analysis

# %% [markdown]
# #### RFM Data Transformation

# %%
# Step 1: Calculate RFM metrics
# Filter th necessary columns

rfm = transaction_df[['Customer_ID', 'Order Date', 'Revenue']]

rfm.head()
# Out:
#    Customer_ID Order Date  Revenue
# 0        11000 2011-01-19  3399.99
# 1        11000 2013-01-18  2341.97
# 2        11000 2013-05-03  2507.03
# 3        11001 2011-01-15  3374.99
# 4        11001 2013-01-16  2419.93

# %%
# Aggregate data for RFM analysis and flatten all columns

rfm = rfm.groupby('Customer_ID').agg({'Order Date':'max', 'Revenue':['count', 'sum']})
rfm.columns = ["_".join(rfm) for rfm in rfm.columns.ravel()]
rfm.head()
# Out:
#             Order Date_max  Revenue_count  Revenue_sum
# Customer_ID
# 11000           2013-05-03              3      8248.99
# 11001           2013-12-10              3      6383.88
# 11002           2013-02-23              3      8114.04
# 11003           2013-05-10              3      8139.29
# 11004           2013-05-01              3      8196.01

# %%
lastTransaction = max(rfm['Order Date_max'])
lastTransaction
# Out:
# Timestamp('2014-01-28 00:00:00')

# %%
rfm["DaysElapsed"]= lastTransaction - rfm['Order Date_max']
rfm.head()
# Out:
#             Order Date_max  Revenue_count  Revenue_sum DaysElapsed
# Customer_ID
# 11000           2013-05-03              3      8248.99    270 days
# 11001           2013-12-10              3      6383.88     49 days
# 11002           2013-02-23              3      8114.04    339 days
# 11003           2013-05-10              3      8139.29    263 days
# 11004           2013-05-01              3      8196.01    272 days

# %%
rfm['DaysElapsed'] = rfm["DaysElapsed"] / np.timedelta64(1, 'D')
rfm.head()
# Out:
#             Order Date_max  Revenue_count  Revenue_sum  DaysElapsed
# Customer_ID
# 11000           2013-05-03              3      8248.99        270.0
# 11001           2013-12-10              3      6383.88         49.0
# 11002           2013-02-23              3      8114.04        339.0
# 11003           2013-05-10              3      8139.29        263.0
# 11004           2013-05-01              3      8196.01        272.0

# %%
# Remove Order Date_max column
rfm.drop('Order Date_max', axis=1, inplace = True)

# Rename rest of columns

rfm.rename(columns={"Revenue_count":"Frequency", "Revenue_sum":"Monetary", "DaysElapsed":"Recency"}, inplace = True)
rfm['Frequency'] = rfm['Frequency'].astype(float)
rfm.head()
# Out:
#              Frequency  Monetary  Recency
# Customer_ID
# 11000              3.0   8248.99    270.0
# 11001              3.0   6383.88     49.0
# 11002              3.0   8114.04    339.0
# 11003              3.0   8139.29    263.0
# 11004              3.0   8196.01    272.0

# %% [markdown]
# #### RFM Scoring

# %%
# Step 2: Add scores to RFm table

quintiles = rfm[['Recency', 'Frequency', 'Monetary']].quantile([.2, .4, .6, .8]).to_dict()
quintiles
# Out:
# {'Recency': {0.2: 72.0, 0.4: 132.0, 0.6: 205.0, 0.8: 287.0},
#  'Frequency': {0.2: 1.0, 0.4: 1.0, 0.6: 1.0, 0.8: 2.0},
#  'Monetary': {0.2: 39.980000000000004,
#   0.4: 91.97,
#   0.6: 1155.48,
#   0.8: 3271.9280000000003}}

# %%
# create scores from 1 to 5 with 1 being the worst and 5 being the best

def r_score(x):
    if x <= quintiles['Recency'][.2]:
        return 5
    elif x <= quintiles['Recency'][.4]:
        return 4
    elif x <= quintiles['Recency'][.6]:
        return 3
    elif x <= quintiles['Recency'][.8]:
        return 2
    else:
        return 1

def fm_score(x, c):
    if x <= quintiles[c][.2]:
        return 1
    elif x <= quintiles[c][.4]:
        return 2
    elif x <= quintiles[c][.6]:
        return 3
    elif x <= quintiles[c][.8]:
        return 4
    else:
        return 5

# %%
rfm['R'] = rfm['Recency'].apply(lambda x: r_score(x))
rfm['F'] = rfm['Frequency'].apply(lambda x: fm_score(x, 'Frequency'))
rfm['M'] = rfm['Monetary'].apply(lambda x: fm_score(x, 'Monetary'))

# %%
rfm['RFM Score'] = rfm['R'].map(str) + rfm['F'].map(str) + rfm['M'].map(str)
rfm.head()
# Out:
#              Frequency  Monetary  Recency  R  F  M RFM Score
# Customer_ID
# 11000              3.0   8248.99    270.0  2  5  5       255
# 11001              3.0   6383.88     49.0  5  5  5       555
# 11002              3.0   8114.04    339.0  1  5  5       155
# 11003              3.0   8139.29    263.0  2  5  5       255
# 11004              3.0   8196.01    272.0  2  5  5       255

# %% [markdown]
# #### RFM Segmentation

# %% [markdown]
# 10 segment classifications (by Recency and Frequency):
#
# * Champions- Bought recently, buy often and spend the most
# * Loyal Customers - Buy on a regular basis. Responsive to promotions.
# * Potential Loyalist - Recent customers with average frequency.
# * New Customers - Bought most recently, but not often.
# * Promising - Recent shoppers, but haven’t spent much.
# * Customers Needing Attention - Above average recency, frequency and monetary values. May not have bought very recently though.
# * About To Sleep - Below average recency and frequency. Will lose them if not reactivated.
# * At Risk - Purchased often but a long time ago. Need to bring them back!
# * Can’t Lose Them - Used to purchase frequently but haven’t returned for a long time.
# * Hibernating - Last purchase was long back and low number of orders. May be lost.

# %% [markdown]
# ![RFM%20Segment%20Matrix.png](attachment:RFM%20Segment%20Matrix.png)

# %%
segt_map = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at risk',
    r'[1-2]5': 'can\'t loose',
    r'3[1-2]': 'about to sleep',
    r'33': 'need attention',
    r'[3-4][4-5]': 'loyal customers',
    r'41': 'promising',
    r'51': 'new customers',
    r'[4-5][2-3]': 'potential loyalists',
    r'5[4-5]': 'champions'
}

rfm['Segment'] = rfm['R'].map(str) + rfm['F'].map(str)
rfm['Segment'] = rfm['Segment'].replace(segt_map, regex=True)
rfm.head()
# Out:
#              Frequency  Monetary  Recency  R  F  M RFM Score      Segment
# Customer_ID
# 11000              3.0   8248.99    270.0  2  5  5       255  can't loose
# 11001              3.0   6383.88     49.0  5  5  5       555    champions
# 11002              3.0   8114.04    339.0  1  5  5       155  can't loose
# 11003              3.0   8139.29    263.0  2  5  5       255  can't loose
# 11004              3.0   8196.01    272.0  2  5  5       255  can't loose

# %%
# plot the distribution of customers over R and F
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

for i, p in enumerate(['R', 'F']):
    parameters = {'R':'Recency', 'F':'Frequency'}
    y = rfm[p].value_counts().sort_index()
    x = y.index
    ax = axes[i]
    bars = ax.bar(x, y, color='silver')
    ax.set_frame_on(False)
    ax.tick_params(left=False, labelleft=False, bottom=False)
    ax.set_title('Distribution of {}'.format(parameters[p]),
                fontsize=14)
    for bar in bars:
        value = bar.get_height()
        if value == y.max():
            bar.set_color('firebrick')
        ax.text(bar.get_x() + bar.get_width() / 2,
                value - 5,
                '{}\n({}%)'.format(int(value), int(value * 100 / y.sum())),
               ha='center',
               va='top',
               color='w')

plt.show()

# plot the distribution of M for RF score
fig, axes = plt.subplots(nrows=5, ncols=5,
                         sharex=False, sharey=True,
                         figsize=(10, 10))

r_range = range(1, 6)
f_range = range(1, 6)
for r in r_range:
    for f in f_range:
        y = rfm[(rfm['R'] == r) & (rfm['F'] == f)]['M'].value_counts().sort_index()
        x = y.index
        ax = axes[r - 1, f - 1]
        bars = ax.bar(x, y, color='silver')
        if r == 5:
            if f == 3:
                ax.set_xlabel('{}\nF'.format(f), va='top')
            else:
                ax.set_xlabel('{}\n'.format(f), va='top')
        if f == 1:
            if r == 3:
                ax.set_ylabel('R\n{}'.format(r))
            else:
                ax.set_ylabel(r)
        ax.set_frame_on(False)
        ax.tick_params(left=False, labelleft=False, bottom=False)
        ax.set_xticks(x)
        ax.set_xticklabels(x, fontsize=8)

        for bar in bars:
            value = bar.get_height()
            if value == y.max():
                bar.set_color('firebrick')
            ax.text(bar.get_x() + bar.get_width() / 2,
                    value,
                    int(value),
                    ha='center',
                    va='bottom',
                    color='k')
fig.suptitle('Distribution of M for each F and R',
             fontsize=14)
plt.tight_layout()
plt.show()

# %%
# count the number of customers in each segment
segments_counts = rfm['Segment'].value_counts().sort_values(ascending=True)

fig, ax = plt.subplots()

bars = ax.barh(range(len(segments_counts)),
              segments_counts,
              color='silver')
ax.set_frame_on(False)
ax.tick_params(left=False,
               bottom=False,
               labelbottom=False)
ax.set_yticks(range(len(segments_counts)))
ax.set_yticklabels(segments_counts.index)

for i, bar in enumerate(bars):
        value = bar.get_width()
        if segments_counts.index[i] in ['champions', 'loyal customers']:
            bar.set_color('firebrick')
        ax.text(value,
                bar.get_y() + bar.get_height()/2,
                '{:,} ({:.2f}%)'.format(int(value),
                                   float(value*100/segments_counts.sum())),
                va='center',
                ha='left'
               )

plt.show()

# %% [markdown]
# ### K-Means Clustering with RFM

# %%
# plot data

rfm.iloc[:,0:3].hist(figsize=(20,10), color = 'mediumslateblue')
pass

# %%
RFM_only = rfm[['Recency', 'Frequency', 'Monetary']]

from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()
RFM_norm1 = standard_scaler.fit_transform(RFM_only)

# %%
from sklearn.preprocessing import RobustScaler
from sklearn import preprocessing

standard_scaler = RobustScaler()
RFM_norm2 = standard_scaler.fit_transform(RFM_only)
RFM_norm2 = preprocessing.normalize(RFM_norm2, norm='l2')
RFM_norm2 = pd.DataFrame(RFM_norm2)
RFM_norm2.columns = ['Recency','Frequency','Monetary ']
RFM_norm2.head()
# Out:
#     Recency  Frequency  Monetary
# 0  0.149590   0.519166   0.841481
# 1 -0.206289   0.613667   0.762141
# 2  0.248707   0.514868   0.820400
# 3  0.140904   0.525054   0.839324
# 4  0.153175   0.521383   0.839463

# %%
RFM_norm2.hist(figsize=(20,10), color = 'mediumslateblue')
pass

# %%
RFM_only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18484 entries, 11000 to 29483
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Recency    18484 non-null  float64
#  1   Frequency  18484 non-null  float64
#  2   Monetary   18484 non-null  float64
# dtypes: float64(3)
# memory usage: 577.6 KB

# %%
RFM_norm1 = pd.DataFrame(RFM_norm1)
RFM_norm1.columns = ['Recency','Frequency','Monetary ']
RFM_norm1.head()
# Out:
#     Recency  Frequency  Monetary
# 0  0.551442   1.365555   3.135647
# 1 -0.959310   1.365555   2.257607
# 2  1.023125   1.365555   3.072117
# 3  0.503590   1.365555   3.084003
# 4  0.565114   1.365555   3.110706

# %%
RFM_norm1.hist(figsize=(20,10), color = 'mediumslateblue')
pass

# %% [markdown]
# #### Hopkins Statistics:

# %% [markdown]
# The Hopkins statistic, is a statistic which gives a value which indicates the cluster tendency, in other words: how well the data can be clustered.
#
# * If the value is between {0.01, ...,0.3}, the data is regularly spaced.
# * If the value is around 0.5, it is random.
# * If the value is between {0.7, ..., 0.99}, it has a high tendency to cluster.

# %%
from sklearn.neighbors import NearestNeighbors
from random import sample
from numpy.random import uniform
import numpy as np
from math import isnan

def hopkins(X):
    d = X.shape[1]
    #d = len(vars) # columns
    n = len(X) # rows
    m = int(0.1 * n)
    nbrs = NearestNeighbors(n_neighbors=1).fit(X.values)

    rand_X = sample(range(0, n, 1), m)

    ujd = []
    wjd = []
    for j in range(0, m):
        u_dist, _ = nbrs.kneighbors(uniform(np.amin(X,axis=0),np.amax(X,axis=0),d).reshape(1, -1), 2, return_distance=True)
        ujd.append(u_dist[0][1])
        w_dist, _ = nbrs.kneighbors(X.iloc[rand_X[j]].values.reshape(1, -1), 2, return_distance=True)
        wjd.append(w_dist[0][1])

    H = sum(ujd) / (sum(ujd) + sum(wjd))
    if isnan(H):
        print(ujd, wjd)
        H = 0

    return H

# %%
hopkins(RFM_norm1)
# Out:
# 0.9983674776283623

# %% [markdown]
# #### K-Means with some K

# %%
# Kmeans with K=5
model_clus5 = KMeans(n_clusters = 5, max_iter=50)
model_clus5.fit(RFM_norm1)
# Out:
# KMeans(max_iter=50, n_clusters=5)

# %% [markdown]
# #### Silhouette Analysis

# %% [markdown]
# * The value of the silhouette score range lies between -1 to 1.
# * score closer to 1 indicates that the data point is very similar to other data points in the cluster,
# * score closer to -1 indicates that the data point is not similar to the data points in its cluster.

# %%
from sklearn.metrics import silhouette_score
sse_ = []
for k in range(2, 21):
    kmeans = KMeans(n_clusters=k, init= 'k-means++', max_iter= 300 ).fit(RFM_norm1)
    sse_.append([k, silhouette_score(RFM_norm1, kmeans.labels_)])

# %%
sns.pointplot(x = list(pd.DataFrame(sse_)[0]), y = list(pd.DataFrame(sse_)[1]), color = 'red')
plt.xlabel('K clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %% [markdown]
# #### Sum of Squared Sums (Elbow Plot)

# %%
# Choose k number of clusters using the Elbow method
def Squared_Sums (features):
    ssd = {}
    for k in range(1, 21):
        kmeans = KMeans(n_clusters= k, init= 'k-means++', max_iter= 300)
        kmeans.fit(features)
        ssd[k] = kmeans.inertia_

    # Plot the ssd values
    sns.pointplot(x = list(ssd.keys()), y = list(ssd.values()), color = 'mediumslateblue')
    plt.xlabel('K clusters')
    plt.ylabel('Sum of Squared distances')
    plt.show()

Squared_Sums(RFM_norm1)

# %% [markdown]
# #### RFM Cluster Analysis

# %% [markdown]
# The most Optimal Num of Clusters(k) is 4 because it has a silhouette score closest to 1 and it's where the Curve for sum of squared distances levels off in the elbow plot.

# %%
seed = 40
kmeans = KMeans(n_clusters= 4, init= 'k-means++', max_iter= 300, random_state = seed)
kmeans.fit(RFM_norm1)
# Assign the clusters to rfm dataframe
rfm['RFM_cluster'] = kmeans.labels_
rfm.head()
# Out:
#              Frequency  Monetary  Recency  R  F  M RFM Score      Segment  \
# Customer_ID
# 11000              3.0   8248.99    270.0  2  5  5       255  can't loose
# 11001              3.0   6383.88     49.0  5  5  5       555    champions
# 11002              3.0   8114.04    339.0  1  5  5       155  can't loose
# 11003              3.0   8139.29    263.0  2  5  5       255  can't loose
# 11004              3.0   8196.01    272.0  2  5  5       255  can't loose
#
#              RFM_cluster
# Customer_ID
# 11000                  0
# 11001                  0
# 11002                  0
# 11003                  0
# 11004                  0

# %%
# analysis of clusters formed
km_clusters_Monetary = 	pd.DataFrame(rfm.groupby(["RFM_cluster"]).Monetary.mean())
km_clusters_Frequency = 	pd.DataFrame(rfm.groupby(["RFM_cluster"]).Frequency.mean())
km_clusters_Recency = 	pd.DataFrame(rfm.groupby(["RFM_cluster"]).Recency.mean())

# %%
Cluster_Means = pd.concat([pd.Series([0,1,2,3]), km_clusters_Monetary, km_clusters_Frequency, km_clusters_Recency], axis=1)
Cluster_Means.columns = ["RFM_cluster", "Monetary_mean", "Frequency_mean", "Recency_mean"]
Cluster_Means.head()
# Out:
#    RFM_cluster  Monetary_mean  Frequency_mean  Recency_mean
# 0            0    4834.740535        2.271838    172.392857
# 1            1     504.183403        1.212339    175.431931
# 2            2     985.743429       20.600000     17.514286
# 3            3    2937.189456        1.000000    856.479012

# %%
g= sns.barplot(x=Cluster_Means.RFM_cluster, y=Cluster_Means.Monetary_mean)
ax=g
for p in ax.patches:
             ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=11, color='black', xytext=(0, -10),
                 textcoords='offset points')

# %%
g=sns.barplot(x=Cluster_Means.RFM_cluster, y=Cluster_Means.Frequency_mean)
ax=g
for p in ax.patches:
             ax.annotate("%.1f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                 textcoords='offset points')

# %%
g=sns.barplot(x=Cluster_Means.RFM_cluster, y=Cluster_Means.Recency_mean)
ax=g
for p in ax.patches:
             ax.annotate("%.1f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                 textcoords='offset points')

# %%
# Remove R, F and M columns
cols = ['R', 'F', 'M']
rfm.drop(cols, axis=1, inplace = True)
# Convert Cuctomer_id back to column
rfm = rfm.reset_index()
rfm.head()
# Out:
#    Customer_ID  Frequency  Monetary  Recency RFM Score      Segment  \
# 0        11000        3.0   8248.99    270.0       255  can't loose
# 1        11001        3.0   6383.88     49.0       555    champions
# 2        11002        3.0   8114.04    339.0       155  can't loose
# 3        11003        3.0   8139.29    263.0       255  can't loose
# 4        11004        3.0   8196.01    272.0       255  can't loose
#
#    RFM_cluster
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
# Visualise clusters with heatmap
# Calculate the mean value in total
total_avg = rfm.iloc[:, 1:4].mean()
total_avg

# Calculate the proportional gap with total mean
cluster_avg_K = rfm.groupby('RFM_cluster').mean().iloc[:, 1:4]
prop_rfm_K = cluster_avg_K/total_avg - 1

# Plot heatmap
sns.heatmap(prop_rfm_K, cmap= 'Blues', fmt= '.2f', annot = True)
plt.plot()
pass

# %%
km_clusters_Segment= rfm.groupby("RFM_cluster")["Segment"].apply(lambda x: x.mode().iloc[0])
hm=km_clusters_Segment.to_frame()
hm.head()
# Out:
#                      Segment
# RFM_cluster
# 0            loyal customers
# 1                hibernating
# 2                  champions
# 3                hibernating

# %%
# Alternative way to visualise 3D data: Snake plot
# Assign cluster column
RFM_norm1['RFM_cluster'] = kmeans.labels_
RFM_norm1

# Melt the dataframe
rfm_melted = pd.melt(frame= RFM_norm1,
                     id_vars= ['RFM_cluster'],
                     var_name = 'Metrics',
                     value_name = 'Scaled value')
rfm_melted.head()
# Out:
#    RFM_cluster  Metrics  Scaled value
# 0            0  Recency      0.551442
# 1            0  Recency     -0.959310
# 2            0  Recency      1.023125
# 3            0  Recency      0.503590
# 4            0  Recency      0.565114

# %%
# PLot snake plot with K-Means
sns.lineplot(x = 'Metrics', y = 'Scaled value', hue = 'RFM_cluster', data = rfm_melted)
plt.legend(loc = 'lower left')
pass

# %%
# Join rfm with transactional table
single_view = pd.merge(trans, rfm, on=['Customer_ID'])
single_view.head()
# Out:
#    Customer_ID  Order Quantity_sum  Order Quantity_mean  \
# 0        11000                 8.0             2.666667
# 1        11001                11.0             3.666667
# 2        11002                 4.0             1.333333
# 3        11003                 9.0             3.000000
# 4        11004                 6.0             2.000000
#
#    Order Quantity_median  Order Quantity_min  Order Quantity_max  Revenue_sum  \
# 0                    2.0                 1.0                 5.0      8248.99
# 1                    4.0                 1.0                 6.0      6383.88
# 2                    1.0                 1.0                 2.0      8114.04
# 3                    4.0                 1.0                 4.0      8139.29
# 4                    2.0                 1.0                 3.0      8196.01
#
#    Revenue_mean  Revenue_median  Revenue_min  ...  Days Elapsed_mean  \
# 0   2749.663333         2507.03      2341.97  ...              417.5
# ...

# %% [markdown]
# ### Tenure and Churning

# %%
transaction_df.columns
# Out:
# Index(['Customer_ID', 'Sales Order Number', 'Order Date', 'Order Quantity',
#        'Revenue', 'Profit', 'Days Elapsed'],
#       dtype='object')

# %%
# Filter relevant columns
tenure = transaction_df[['Customer_ID','Order Date']]
tenure = tenure.groupby('Customer_ID').agg({'Order Date':['min', 'max']})
tenure.columns = ["_".join(tenure) for tenure in tenure.columns.ravel()]
tenure.head()
# Out:
#             Order Date_min Order Date_max
# Customer_ID
# 11000           2011-01-19     2013-05-03
# 11001           2011-01-15     2013-12-10
# 11002           2011-01-07     2013-02-23
# 11003           2010-12-29     2013-05-10
# 11004           2011-01-23     2013-05-01

# %%
# Calculate tenure
tenure['Tenure_months'] = tenure['Order Date_max'] - tenure['Order Date_min']
tenure['Tenure_months'] = tenure['Tenure_months'] / np.timedelta64(1,'M')
tenure.head()
# Out:
#             Order Date_min Order Date_max  Tenure_months
# Customer_ID
# 11000           2011-01-19     2013-05-03      27.433828
# 11001           2011-01-15     2013-12-10      34.826177
# 11002           2011-01-07     2013-02-23      25.561100
# 11003           2010-12-29     2013-05-10      28.353765
# 11004           2011-01-23     2013-05-01      27.236699

# %%
# Create target variable: Churn or no churn?
# Determine elapsed time threshold for churning
tenure['Tenure_months'].describe()
# Out:
# count    18484.000000
# mean         5.171685
# std          8.513386
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          8.903674
# max         35.778969
# Name: Tenure_months, dtype: float64

# %%
tenure['Tenure_months'].hist(color = 'mediumslateblue')
pass

# %%
# Add Recency to the table
tenure['Recency'] = (lastTransaction  - tenure['Order Date_max']) / np.timedelta64(1,'D')
tenure['Days since first Transaction'] = (lastTransaction  - tenure['Order Date_min']) / np.timedelta64(1,'D')
tenure.head()
# Out:
#             Order Date_min Order Date_max  Tenure_months  Recency  \
# Customer_ID
# 11000           2011-01-19     2013-05-03      27.433828    270.0
# 11001           2011-01-15     2013-12-10      34.826177     49.0
# 11002           2011-01-07     2013-02-23      25.561100    339.0
# 11003           2010-12-29     2013-05-10      28.353765    263.0
# 11004           2011-01-23     2013-05-01      27.236699    272.0
#
#              Days since first Transaction
# Customer_ID
# 11000                              1105.0
# 11001                              1109.0
# 11002                              1117.0
# 11003                              1126.0
# 11004                              1101.0

# %%
# Define days needed to elapse for potential churning (8 months)
churn_days = 243

def churn(x):
    '''
    Determines churning or not.
    If Recency is equal to or greater than 243 days, customer has churned.
    '''
    if x >= churn_days:
        return 1
    else:
        return 0

# Apply the function to Churn column
tenure['Churn']= [churn(x) for x in tenure.Recency]

# %%
# Remove columns
cols = ['Order Date_min', 'Order Date_max', 'Recency']
tenure.drop(cols, axis=1, inplace = True)
tenure = tenure.reset_index()
tenure.head()
# Out:
#    Customer_ID  Tenure_months  Days since first Transaction  Churn
# 0        11000      27.433828                        1105.0      1
# 1        11001      34.826177                        1109.0      0
# 2        11002      25.561100                        1117.0      1
# 3        11003      28.353765                        1126.0      1
# 4        11004      27.236699                        1101.0      1

# %%
# Join tenure with transactional and rfm tables
single_view = pd.merge(single_view, tenure, on=['Customer_ID'])
single_view.head()
# Out:
#    Customer_ID  Order Quantity_sum  Order Quantity_mean  \
# 0        11000                 8.0             2.666667
# 1        11001                11.0             3.666667
# 2        11002                 4.0             1.333333
# 3        11003                 9.0             3.000000
# 4        11004                 6.0             2.000000
#
#    Order Quantity_median  Order Quantity_min  Order Quantity_max  Revenue_sum  \
# 0                    2.0                 1.0                 5.0      8248.99
# 1                    4.0                 1.0                 6.0      6383.88
# 2                    1.0                 1.0                 2.0      8114.04
# 3                    4.0                 1.0                 4.0      8139.29
# 4                    2.0                 1.0                 3.0      8196.01
#
#    Revenue_mean  Revenue_median  Revenue_min  ...  Days Elapsed_max  \
# 0   2749.663333         2507.03      2341.97  ...             730.0
# ...

# %% [markdown]
# ### Demographic Data

# %% [markdown]
# #### Data Importing

# %%
# Open connection to SQL

conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=G-K-FRASER;'
                      'Database=AdventureWorksDW2017;'
                      'Trust_Connection= yes;')

# %%
# SQL query; Demographic data
Demos=pd.read_sql_query("""
SELECT
	[CustomerKey] AS [Customer_ID],
	[BirthDate] AS [Birth_date],
	[MaritalStatus] AS [Marital_status],
	[Gender],
	[YearlyIncome] AS [Yearly_income],
	[TotalChildren] AS [Total_children],
	[NumberChildrenAtHome] AS [Number_children_at_home],
	[EnglishEducation] AS Education,
	[EnglishOccupation] AS Occupation,
	[HouseOwnerFlag] AS [House_ownership],
	[NumberCarsOwned] AS [Car_ownership],
	[CommuteDistance] AS [Commute_distance]
FROM [dbo].[DimCustomer];
""", conn)

# Close connection
conn.close()

# %% [markdown]
# #### Data Exploration

# %%
Demos.head()
# Out:
#    Customer_ID  Birth_date Marital_status Gender  Yearly_income  \
# 0        11000  1971-10-06              M      M        90000.0
# 1        11001  1976-05-10              S      M        60000.0
# 2        11002  1971-02-09              M      M        60000.0
# 3        11003  1973-08-14              S      F        70000.0
# 4        11004  1979-08-05              S      F        80000.0
#
#    Total_children  Number_children_at_home  Education    Occupation  \
# 0               2                        0  Bachelors  Professional
# 1               3                        3  Bachelors  Professional
# 2               3                        3  Bachelors  Professional
# 3               0                        0  Bachelors  Professional
# 4               5                        5  Bachelors  Professional
#
#   House_ownership  Car_ownership Commute_distance
# 0               1              0        1-2 Miles
# 1               0              1        0-1 Miles
# ...

# %%
Demos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18484 entries, 0 to 18483
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer_ID              18484 non-null  int64
#  1   Birth_date               18484 non-null  object
#  2   Marital_status           18484 non-null  object
#  3   Gender                   18484 non-null  object
#  4   Yearly_income            18484 non-null  float64
#  5   Total_children           18484 non-null  int64
#  6   Number_children_at_home  18484 non-null  int64
#  7   Education                18484 non-null  object
#  8   Occupation               18484 non-null  object
#  9   House_ownership          18484 non-null  object
#  10  Car_ownership            18484 non-null  int64
#  11  Commute_distance         18484 non-null  object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.7+ MB

# %% [markdown]
# #### Data Transformation

# %%
# Calculate age
def Age(birth_date):
    '''
    Calculates days between birth date and
    date of last transaction available
    '''
    return lastTransaction - birth_date

# Convert Birth Date into datetime
Demos['Birth_date'] = pd.to_datetime(Demos['Birth_date'])
# Apply Age function and convert days into years
Demos['Age'] = Demos['Birth_date'].apply(Age) / np.timedelta64(1, 'Y')
#demographics['Age'] = demographics['Age'].astype(int)
Demos.head()
# Out:
#    Customer_ID Birth_date Marital_status Gender  Yearly_income  \
# 0        11000 1971-10-06              M      M        90000.0
# 1        11001 1976-05-10              S      M        60000.0
# 2        11002 1971-02-09              M      M        60000.0
# 3        11003 1973-08-14              S      F        70000.0
# 4        11004 1979-08-05              S      F        80000.0
#
#    Total_children  Number_children_at_home  Education    Occupation  \
# 0               2                        0  Bachelors  Professional
# 1               3                        3  Bachelors  Professional
# 2               3                        3  Bachelors  Professional
# 3               0                        0  Bachelors  Professional
# 4               5                        5  Bachelors  Professional
#
#   House_ownership  Car_ownership Commute_distance        Age
# 0               1              0        1-2 Miles  42.314353
# ...

# %%
# Create a new field for age group
# Show distribution to determine bins
Demos['Age'].hist(color = 'mediumslateblue')
pass

# %%
# Create bands
bins = [0, 30, 40, 50, 60, np.inf]
names = ['20s', '30s','40s', '50s','60s or older']
Demos['Age_group'] = pd.cut(Demos['Age'], bins, labels = names,include_lowest = True)

# %%
# Create a new field for income group
# Show distribution to determine bins
Demos['Yearly_income'].hist(color = 'mediumslateblue')
pass

# %%
# Create bands
bins = [0, 35000, 70000, 105000, np.inf]
names = ['Low Class','Low-middle Class', 'Upper-middle Class', 'High Class']
Demos['Income_group']= pd.cut(Demos['Yearly_income'], bins, labels = names,include_lowest = True)
Demos.head()
# Out:
#    Customer_ID Birth_date Marital_status Gender  Yearly_income  \
# 0        11000 1971-10-06              M      M        90000.0
# 1        11001 1976-05-10              S      M        60000.0
# 2        11002 1971-02-09              M      M        60000.0
# 3        11003 1973-08-14              S      F        70000.0
# 4        11004 1979-08-05              S      F        80000.0
#
#    Total_children  Number_children_at_home  Education    Occupation  \
# 0               2                        0  Bachelors  Professional
# 1               3                        3  Bachelors  Professional
# 2               3                        3  Bachelors  Professional
# 3               0                        0  Bachelors  Professional
# 4               5                        5  Bachelors  Professional
#
#   House_ownership  Car_ownership Commute_distance        Age Age_group  \
# 0               1              0        1-2 Miles  42.314353       40s
# ...

# %%
# Join transactional and demographic tables into a single view table
single_view = pd.merge(single_view, Demos, on ='Customer_ID')
single_view.head()
# Out:
#    Customer_ID  Order Quantity_sum  Order Quantity_mean  \
# 0        11000                 8.0             2.666667
# 1        11001                11.0             3.666667
# 2        11002                 4.0             1.333333
# 3        11003                 9.0             3.000000
# 4        11004                 6.0             2.000000
#
#    Order Quantity_median  Order Quantity_min  Order Quantity_max  Revenue_sum  \
# 0                    2.0                 1.0                 5.0      8248.99
# 1                    4.0                 1.0                 6.0      6383.88
# 2                    1.0                 1.0                 2.0      8114.04
# 3                    4.0                 1.0                 4.0      8139.29
# 4                    2.0                 1.0                 3.0      8196.01
#
#    Revenue_mean  Revenue_median  Revenue_min  ...  Total_children  \
# 0   2749.663333         2507.03      2341.97  ...               2
# ...

# %%
Demos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18484 entries, 0 to 18483
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer_ID              18484 non-null  int64
#  1   Birth_date               18484 non-null  datetime64[ns]
#  2   Marital_status           18484 non-null  object
#  3   Gender                   18484 non-null  object
#  4   Yearly_income            18484 non-null  float64
#  5   Total_children           18484 non-null  int64
#  6   Number_children_at_home  18484 non-null  int64
#  7   Education                18484 non-null  object
#  8   Occupation               18484 non-null  object
#  9   House_ownership          18484 non-null  object
#  10  Car_ownership            18484 non-null  int64
#  11  Commute_distance         18484 non-null  object
#  12  Age                      18484 non-null  float64
# ...

# %% [markdown]
# ### Attitudinal Data

# %% [markdown]
# #### Data Importing

# %%
# Establish an open connection to SQL
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=G-K-FRASER;'
                      'Database=AdventureWorksDW2017;'
                      'Trusted_Connection=yes;')

# %%
# SQL query; Attitudinal data
Attitudinal=pd.read_sql_query("""
SELECT
	FIS.[CustomerKey] AS [Customer_ID],
	FIS.[SalesOrderNumber] AS [Sales_order_number],
	FIS.[SalesOrderLineNumber] AS [Sales_order_line_number],
	DSR.[SalesReasonReasonType] AS [Sales_reason_type],
	DSR.[SalesReasonName] AS [Sales_reason]
FROM [dbo].[FactInternetSales] AS FIS
LEFT JOIN [dbo].[FactInternetSalesReason] AS FISR
ON FIS.[SalesOrderNumber] = FISR.[SalesOrderNumber]
LEFT JOIN [dbo].[DimSalesReason] AS DSR
ON DSR.[SalesReasonKey] = FISR.[SalesReasonKey];
""", conn)

# Close connection
conn.close()

# %% [markdown]
# #### Data Exploration

# %%
Attitudinal.head()
# Out:
#    Customer_ID Sales_order_number  Sales_order_line_number Sales_reason_type  \
# 0        21768            SO43697                        1             Other
# 1        21768            SO43697                        1             Other
# 2        27645            SO43702                        1             Other
# 3        27645            SO43702                        1             Other
# 4        16624            SO43703                        1             Other
#
#    Sales_reason
# 0  Manufacturer
# 1       Quality
# 2  Manufacturer
# 3       Quality
# 4  Manufacturer

# %%
Attitudinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194586 entries, 0 to 194585
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Customer_ID              194586 non-null  int64
#  1   Sales_order_number       194586 non-null  object
#  2   Sales_order_line_number  194586 non-null  int64
#  3   Sales_reason_type        188157 non-null  object
#  4   Sales_reason             188157 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 7.4+ MB

# %%
# Check for potential duplicate rows
print('Number of duplicates:', Attitudinal.duplicated().sum())
# Out:
# Number of duplicates: 123642

# %%
# Remove duplicates
Attitudinal.drop_duplicates(subset=None, keep='first', inplace= True)

# %%
# Replace missing values in Sales_reason_type and Sales_reason_type with mode
Attitudinal = Attitudinal.fillna(Attitudinal.mode().iloc[0])
Attitudinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70944 entries, 0 to 194585
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer_ID              70944 non-null  int64
#  1   Sales_order_number       70944 non-null  object
#  2   Sales_order_line_number  70944 non-null  int64
#  3   Sales_reason_type        70944 non-null  object
#  4   Sales_reason             70944 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 3.2+ MB

# %% [markdown]
# #### Data Transformation

# %%
# Summarise data per customer
# Apply One Hot encoding for Sales_reason_type and Sales_reason
cols = ['Sales_reason_type', 'Sales_reason']
Attitudinal = pd.get_dummies(data = Attitudinal, columns = cols)
Attitudinal.head()
# Out:
#    Customer_ID Sales_order_number  Sales_order_line_number  \
# 0        21768            SO43697                        1
# 1        21768            SO43697                        1
# 2        27645            SO43702                        1
# 3        27645            SO43702                        1
# 4        16624            SO43703                        1
#
#    Sales_reason_type_Marketing  Sales_reason_type_Other  \
# 0                            0                        1
# 1                            0                        1
# 2                            0                        1
# 3                            0                        1
# 4                            0                        1
#
#    Sales_reason_type_Promotion  Sales_reason_Manufacturer  \
# 0                            0                          1
# 1                            0                          0
# 2                            0                          1
# ...

# %%
Attitudinal.columns
# Out:
# Index(['Customer_ID', 'Sales_order_number', 'Sales_order_line_number',
#        'Sales_reason_type_Marketing', 'Sales_reason_type_Other',
#        'Sales_reason_type_Promotion', 'Sales_reason_Manufacturer',
#        'Sales_reason_On Promotion', 'Sales_reason_Other', 'Sales_reason_Price',
#        'Sales_reason_Quality', 'Sales_reason_Review',
#        'Sales_reason_Television  Advertisement'],
#       dtype='object')

# %%
# Aggregate data per customer
Attitudinal = Attitudinal.groupby('Customer_ID').agg({'Sales_reason_type_Marketing': 'max',
                                              'Sales_reason_type_Other': 'max',
                                              'Sales_reason_type_Promotion': 'max',
                                              'Sales_reason_Manufacturer': 'max',
                                              'Sales_reason_On Promotion': 'max',
                                              'Sales_reason_Other': 'max',
                                              'Sales_reason_Price': 'max',
                                              'Sales_reason_Quality': 'max',
                                              'Sales_reason_Review': 'max',
                                              'Sales_reason_Television  Advertisement': 'max'}).reset_index()
Attitudinal.head()
# Out:
#    Customer_ID  Sales_reason_type_Marketing  Sales_reason_type_Other  \
# 0        11000                            0                        1
# 1        11001                            0                        1
# 2        11002                            0                        1
# 3        11003                            0                        1
# 4        11004                            0                        1
#
#    Sales_reason_type_Promotion  Sales_reason_Manufacturer  \
# 0                            1                          0
# 1                            0                          0
# 2                            1                          0
# 3                            0                          0
# 4                            0                          0
#
#    Sales_reason_On Promotion  Sales_reason_Other  Sales_reason_Price  \
# 0                          1                   0                   1
# ...

# %%
#join drivers with transactional and cust_dem tables

single_view = pd.merge(single_view, Attitudinal, on = 'Customer_ID')
single_view.head().transpose()
# Out:
#                                                           0  \
# Customer_ID                                           11000
# Order Quantity_sum                                        8
# Order Quantity_mean                                 2.66667
# Order Quantity_median                                     2
# Order Quantity_min                                        1
# Order Quantity_max                                        5
# Revenue_sum                                         8248.99
# Revenue_mean                                        2749.66
# Revenue_median                                      2507.03
# Revenue_min                                         2341.97
# Revenue_max                                         3399.99
# Profit_sum                                          3513.69
# Profit_mean                                         1171.23
# Profit_median                                       1068.13
# Profit_min                                          957.725
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Creating Historical and Live Data (For Model and Scoring)

# %%
# PLot countplot for target variable
sns.countplot(data = single_view, x = 'Churn', color = 'steelblue')
pass

# %%
single_view['Churn'].value_counts()
# Out:
# 0    12973
# 1     5511
# Name: Churn, dtype: int64

# %%
# Hold out sample for data scoring; 60% of non churners
non_churners = single_view[single_view['Churn'] == 0]
non_churners.head()
# Out:
#     Customer_ID  Order Quantity_sum  Order Quantity_mean  \
# 1         11001                11.0             3.666667
# 12        11012                 5.0             2.500000
# 13        11013                 5.0             2.500000
# 17        11017                 4.0             1.333333
# 18        11018                 7.0             2.333333
#
#     Order Quantity_median  Order Quantity_min  Order Quantity_max  \
# 1                     4.0                 1.0                 6.0
# 12                    2.5                 2.0                 3.0
# 13                    2.5                 2.0                 3.0
# 17                    1.0                 1.0                 2.0
# 18                    2.0                 1.0                 4.0
#
#     Revenue_sum  Revenue_mean  Revenue_median  Revenue_min  ...  \
# 1       6383.88       2127.96         2419.93       588.96  ...
# 12        81.26         40.63           40.63         6.28  ...
# ...

# %%
score_pct = 0.6
model_data, score_data = train_test_split(non_churners,
                                          test_size = score_pct,
                                          random_state = seed)

len(model_data)
# Out:
# 5189

# %%
# Concat non churner model data with churner data
churners = single_view[single_view['Churn'] == 1]
model_data = pd.concat([model_data, churners], ignore_index=True)
model_data.shape
# Out:
# (10700, 54)

# %%
model_data.head().transpose()
# Out:
#                                                           0  \
# Customer_ID                                           12232
# Order Quantity_sum                                        3
# Order Quantity_mean                                     1.5
# Order Quantity_median                                   1.5
# Order Quantity_min                                        1
# Order Quantity_max                                        2
# Revenue_sum                                          4376.4
# Revenue_mean                                         2188.2
# Revenue_median                                       2188.2
# Revenue_min                                         2071.42
# Revenue_max                                         2304.98
# Profit_sum                                          2002.83
# Profit_mean                                         1001.41
# Profit_median                                       1001.41
# Profit_min                                          953.564
# ...

# %% [markdown]
# ### Missing and Inconsistent Data

# %%
# Double check for missing values and duplicates
model_data.isnull().sum()[model_data.isnull().sum()!=0]
# Out:
# Days Elapsed_mean      7128
# Days Elapsed_median    7128
# Days Elapsed_min       7128
# Days Elapsed_max       7128
# dtype: int64

# %%
# Check for potential duplicate rows
print('Number of duplicates:', model_data.duplicated().sum())
# Out:
# Number of duplicates: 0

# %% [markdown]
# ### Categorical Data

# %%
# Get columns
cols = model_data.columns
cols
# Out:
# Index(['Customer_ID', 'Order Quantity_sum', 'Order Quantity_mean',
#        'Order Quantity_median', 'Order Quantity_min', 'Order Quantity_max',
#        'Revenue_sum', 'Revenue_mean', 'Revenue_median', 'Revenue_min',
#        'Revenue_max', 'Profit_sum', 'Profit_mean', 'Profit_median',
#        'Profit_min', 'Profit_max', 'Days Elapsed_sum', 'Days Elapsed_mean',
#        'Days Elapsed_median', 'Days Elapsed_min', 'Days Elapsed_max',
#        'Frequency', 'Monetary', 'Recency', 'RFM Score', 'Segment',
#        'RFM_cluster', 'Tenure_months', 'Days since first Transaction', 'Churn',
#        'Birth_date', 'Marital_status', 'Gender', 'Yearly_income',
#        'Total_children', 'Number_children_at_home', 'Education', 'Occupation',
#        'House_ownership', 'Car_ownership', 'Commute_distance', 'Age',
#        'Age_group', 'Income_group', 'Sales_reason_type_Marketing',
#        'Sales_reason_type_Other', 'Sales_reason_type_Promotion',
# ...

# %%
# Delete fields that are of no use for our modelling
# Revenue_sum is the same as monetary
deleted = ['Customer_ID', 'Order Quantity_min', 'Birth_date','Days since first Transaction',
           'Days Elapsed_sum', 'Days Elapsed_mean', 'Days Elapsed_median',
           'Days Elapsed_min','Days Elapsed_max', 'RFM Score', 'Recency','Monetary','Frequency']

select_data = model_data.drop(deleted, axis = 1)

# %%
model_data.columns
# Out:
# Index(['Customer_ID', 'Order Quantity_sum', 'Order Quantity_mean',
#        'Order Quantity_median', 'Order Quantity_min', 'Order Quantity_max',
#        'Revenue_sum', 'Revenue_mean', 'Revenue_median', 'Revenue_min',
#        'Revenue_max', 'Profit_sum', 'Profit_mean', 'Profit_median',
#        'Profit_min', 'Profit_max', 'Days Elapsed_sum', 'Days Elapsed_mean',
#        'Days Elapsed_median', 'Days Elapsed_min', 'Days Elapsed_max',
#        'Frequency', 'Monetary', 'Recency', 'RFM Score', 'Segment',
#        'RFM_cluster', 'Tenure_months', 'Days since first Transaction', 'Churn',
#        'Birth_date', 'Marital_status', 'Gender', 'Yearly_income',
#        'Total_children', 'Number_children_at_home', 'Education', 'Occupation',
#        'House_ownership', 'Car_ownership', 'Commute_distance', 'Age',
#        'Age_group', 'Income_group', 'Sales_reason_type_Marketing',
#        'Sales_reason_type_Other', 'Sales_reason_type_Promotion',
# ...

# %%
# Filter categorical variables

#'Segment', 'RFM Score'
cat = ['RFM_cluster', 'Marital_status', 'Gender', 'Segment', 'House_ownership','Number_children_at_home','Car_ownership',
       'Total_children', 'Education', 'Occupation', 'Commute_distance', 'Age_group', 'Income_group', 'Sales_reason_type_Marketing',
       'Sales_reason_type_Other', 'Sales_reason_type_Promotion', 'Sales_reason_Manufacturer',
       'Sales_reason_On Promotion', 'Sales_reason_Other', 'Sales_reason_Price', 'Sales_reason_Quality',
       'Sales_reason_Review', 'Sales_reason_Television  Advertisement']

# %%
# Get distribution/frequency per category
for var in cat:
 print(select_data[var].value_counts())
# Out:
# 1    7909
# 0    2371
# 3     405
# 2      15
# Name: RFM_cluster, dtype: int64
# M    5793
# S    4907
# Name: Marital_status, dtype: int64
# M    5423
# F    5277
# Name: Gender, dtype: int64
# hibernating        4565
# at risk            1534
# loyal customers    1238
# about to sleep      923
# new customers       820
# promising           820
# champions           664
# can't loose         136
# Name: Segment, dtype: int64
# 1    7243
# 0    3457
# Name: House_ownership, dtype: int64
# 0    6476
# 1    1445
# 2     943
# 3     703
# 4     583
# 5     550
# Name: Number_children_at_home, dtype: int64
# 2    3789
# 1    2827
# 0    2460
# 3     927
# 4     697
# Name: Car_ownership, dtype: int64
# 0    2972
# 2    2183
# 1    2145
# 4    1318
# 3    1261
# 5     821
# Name: Total_children, dtype: int64
# Bachelors              3053
# Partial College        2929
# High School            1913
# Graduate Degree        1876
# Partial High School     929
# ...

# %%
# PLot distribution/frequency per category
cat_df = select_data[cat]
plt.rcParams['figure.figsize'] = (15, 5) # Chart sizes

for i, col in enumerate(cat_df.columns):
   plt.figure(i)
   sns.countplot(x=col, data=cat_df, color = 'mediumslateblue')
# Out:
# <ipython-input-96-f311653135b2>:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(i)

# %%
# Encode categorical data (besides drivers which are already binary)
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# 'RFM Score', 'Segment', 'Marital_status', 'Gender','RFM_cluster','Number_children_at_home','House_ownership',
# 'Car_ownership', 'Total_children'
dummies = ['Education', 'Occupation', 'Segment', 'Commute_distance', 'Age_group', 'Income_group']

encoded_data = pd.get_dummies(select_data, columns = [v for v in dummies], drop_first = False)
encoded_data['Marital_status_Cat'] = labelencoder.fit_transform(encoded_data['Marital_status'])
encoded_data['Gender_Cat'] = labelencoder.fit_transform(encoded_data['Gender'])

encoded_data["House_ownership"] = encoded_data["House_ownership"].astype(str).astype(int)

# %%
# Get frequency of target variable
encoded_data['Churn'].value_counts()
# Out:
# 1    5511
# 0    5189
# Name: Churn, dtype: int64

# %%
encoded_data.columns
# Out:
# Index(['Order Quantity_sum', 'Order Quantity_mean', 'Order Quantity_median',
#        'Order Quantity_max', 'Revenue_sum', 'Revenue_mean', 'Revenue_median',
#        'Revenue_min', 'Revenue_max', 'Profit_sum', 'Profit_mean',
#        'Profit_median', 'Profit_min', 'Profit_max', 'RFM_cluster',
#        'Tenure_months', 'Churn', 'Marital_status', 'Gender', 'Yearly_income',
#        'Total_children', 'Number_children_at_home', 'House_ownership',
#        'Car_ownership', 'Age', 'Sales_reason_type_Marketing',
#        'Sales_reason_type_Other', 'Sales_reason_type_Promotion',
#        'Sales_reason_Manufacturer', 'Sales_reason_On Promotion',
#        'Sales_reason_Other', 'Sales_reason_Price', 'Sales_reason_Quality',
#        'Sales_reason_Review', 'Sales_reason_Television  Advertisement',
#        'Education_Bachelors', 'Education_Graduate Degree',
#        'Education_High School', 'Education_Partial College',
#        'Education_Partial High School', 'Occupation_Clerical',
# ...

# %%
sns.countplot(x = encoded_data['Churn'], color = 'mediumslateblue')
pass

# %% [markdown]
# ### Continuous Data

# %%
# Filter continuous variables
cont = [v for v in cols if v not in cat and v not in deleted and v != 'Churn']

# %%
cont
# Out:
# ['Order Quantity_sum',
#  'Order Quantity_mean',
#  'Order Quantity_median',
#  'Order Quantity_max',
#  'Revenue_sum',
#  'Revenue_mean',
#  'Revenue_median',
#  'Revenue_min',
#  'Revenue_max',
#  'Profit_sum',
#  'Profit_mean',
#  'Profit_median',
#  'Profit_min',
#  'Profit_max',
#  'Tenure_months',
#  'Yearly_income',
#  'Age']

# %%
# Get quick stats
encoded_data[cont].describe().transpose()
# Out:
#                          count          mean           std           min  \
# Order Quantity_sum     10700.0      3.101869      2.424772      1.000000
# Order Quantity_mean    10700.0      2.212272      0.937394      1.000000
# Order Quantity_median  10700.0      2.208972      0.948271      1.000000
# Order Quantity_max     10700.0      2.509065      1.109237      1.000000
# Revenue_sum            10700.0   1564.452192   2058.768118      2.290000
# Revenue_mean           10700.0    946.434877   1078.391366      2.290000
# Revenue_median         10700.0    946.152638   1078.436042      2.290000
# Revenue_min            10700.0    804.330448    968.617638      2.290000
# Revenue_max            10700.0   1089.174564   1261.702020      2.290000
# Profit_sum             10700.0    640.760027    845.794605      1.433500
# Profit_mean            10700.0    385.680234    435.086934      1.433500
# Profit_median          10700.0    385.855132    435.706242      1.433500
# ...

# %%
# Plot boxplots
encoded_data[cont].plot(kind='box', subplots=True, figsize=(20,40),
                      layout=(9,4), sharex=False, sharey=False)
plt.show()

# %%
# PLot histograms
encoded_data[cont].hist(figsize=(20,40), color = 'mediumslateblue')
pass

# %%
 encoded_data= encoded_data.drop(['Marital_status','Gender'], axis = 1)

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Feature Voting

# %%
encoded_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10700 entries, 0 to 10699
# Data columns (total 67 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Order Quantity_sum                      10700 non-null  float64
#  1   Order Quantity_mean                     10700 non-null  float64
#  2   Order Quantity_median                   10700 non-null  float64
#  3   Order Quantity_max                      10700 non-null  float64
#  4   Revenue_sum                             10700 non-null  float64
#  5   Revenue_mean                            10700 non-null  float64
#  6   Revenue_median                          10700 non-null  float64
#  7   Revenue_min                             10700 non-null  float64
#  8   Revenue_max                             10700 non-null  float64
#  9   Profit_sum                              10700 non-null  float64
# ...

# %%
segments = ['Segment_about to sleep', 'Segment_hibernating',
       'Segment_at risk', "Segment_can't loose", 'Segment_champions', 'Segment_loyal customers',
       'Segment_new customers', 'Segment_promising']

X = encoded_data[segments]
y = encoded_data['Churn']

from sklearn.ensemble import RandomForestClassifier

from yellowbrick.model_selection import FeatureImportances

model2 = GradientBoostingClassifier(n_estimators=10)
viz2 = FeatureImportances(model2, topn=7)
viz2.fit(X, y)
viz2.show('xtick', labelsize=1)

# %%
# pip install xverse

# %%
# Split dataset into features and target variable
X = encoded_data[encoded_data.columns.difference(['Segment_about to sleep',
       "Segment_can't loose", 'Segment_at risk','Segment_champions',
       'Segment_loyal customers','Segment_new customers','Segment_promising','Churn'])]
y = encoded_data['Churn']

# %%
# model = RandomForestClassifier(n_estimators=10)
# viz = FeatureImportances(model, topn=5)
# viz.fit(X, y)
# viz.show()

# %%
from xverse.ensemble import VotingSelector
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import warnings                        # To ignore any warnings
warnings.filterwarnings("ignore")

# %%
# call Votingselector with minimum_votes of 2
clf = VotingSelector(minimum_votes=2)
clf.fit(X, y)
# Out:
# VotingSelector(minimum_votes=2, no_of_features=29,
#                selection_techniques=['WOE', 'RF', 'RFE', 'ETC', 'CS', 'L_ONE'])

# %%
#show important features
clf.feature_importances_
# Out:
#                              Variable_Name  Information_Value  Random_Forest  \
# 0                      Segment_hibernating           2.353607       0.403774
# 1                            Tenure_months           0.140311       0.074216
# 2                       Order Quantity_sum           0.111384       0.016506
# 3                       Sales_reason_Price           0.056666       0.001486
# 4                     Sales_reason_Quality           0.050976       0.003813
# 5                Sales_reason_Manufacturer           0.044258       0.003116
# 6                       Order Quantity_max           0.043203       0.006641
# 7                      Order Quantity_mean           0.041031       0.007665
# 8                              Revenue_sum           0.021456       0.031609
# 9                               Profit_sum           0.020769       0.031055
# 10                             RFM_cluster           0.020140       0.014851
# ...

# %%
# votes
clf.feature_votes_
# Out:
#                              Variable_Name  Information_Value  Random_Forest  \
# 0                      Segment_hibernating                  1              1
# 6                       Order Quantity_max                  1              1
# 1                            Tenure_months                  1              1
# 22                 Number_children_at_home                  1              1
# 10                             RFM_cluster                  1              1
# 7                      Order Quantity_mean                  1              1
# 28                             Profit_mean                  1              1
# 2                       Order Quantity_sum                  1              1
# 17                              Profit_max                  1              1
# 20                           Car_ownership                  1              1
# 9                               Profit_sum                  1              1
# ...

# %%
clf.feature_votes_.loc[(clf.feature_votes_['Votes'] >= 2)]
# Out:
#                              Variable_Name  Information_Value  Random_Forest  \
# 0                      Segment_hibernating                  1              1
# 6                       Order Quantity_max                  1              1
# 1                            Tenure_months                  1              1
# 22                 Number_children_at_home                  1              1
# 10                             RFM_cluster                  1              1
# 7                      Order Quantity_mean                  1              1
# 28                             Profit_mean                  1              1
# 2                       Order Quantity_sum                  1              1
# 17                              Profit_max                  1              1
# 20                           Car_ownership                  1              1
# 9                               Profit_sum                  1              1
# ...

# %%
#clf.transform(X).columns
features = clf.feature_votes_.loc[(clf.feature_votes_['Votes'] >= 4)]['Variable_Name']

# %%
# feature_df = encoded_data[['Segment_hibernating', 'Segment_new customers', 'RFM Score_411',
#        'RFM Score_312', 'Revenue_mean', 'RFM Score_313', 'RFM Score_311',
#        'Segment_at risk', 'Recency', 'RFM Score_245', 'RFM Score_145',
#        'RFM Score_113', 'RFM Score_112', 'Revenue_median', 'RFM Score_114',
#        'Segment_promising', 'Profit_min', 'RFM Score_111', 'Frequency',
#        'Segment_loyal customers', 'Tenure_months', 'Order Quantity_sum',
#        'Order Quantity_max', 'Segment_about to sleep','Churn']]

feature_df = encoded_data[list(features) + ['Churn']]

# %%
feature_df
# Out:
#        Segment_hibernating  Order Quantity_max  Tenure_months  \
# 0                        0                 2.0      12.222017
# 1                        0                 3.0       0.000000
# 2                        0                 2.0       7.326639
# 3                        0                 4.0       0.000000
# 4                        0                 2.0       0.000000
# ...                    ...                 ...            ...
# 10695                    1                 1.0       0.000000
# 10696                    1                 1.0       0.000000
# 10697                    1                 1.0       0.000000
# 10698                    1                 1.0       0.000000
# 10699                    1                 1.0       0.000000
#
#        Number_children_at_home  RFM_cluster  Order Quantity_mean  Profit_mean  \
# 0                            0            0                  1.5   1001.41305
# ...

# %%
#pip install yellowbrick

# %%
# Load the classification data set

model = RandomForestClassifier(n_estimators=10)
viz = FeatureImportances(model, topn=5)
viz.fit(X, y)
viz.show()

# %%
# model2 = GradientBoostingClassifier(n_estimators=10)
# viz2 = FeatureImportances(model, topn=10)
# viz2.fit(X, y)
# viz.show()

# %% [markdown]
# ### Multicollinearity

# %% [markdown]
# #### VIF - Variable Inflation Factors

# %%
features1= feature_df.drop('Churn', axis=1)

# %%
def calculate_vif(features):
    vif = pd.DataFrame()
    vif["Features"] = features.columns
    vif["VIF"] = [variance_inflation_factor(features.values, i) for i in range(features.shape[1])]
    return(vif)

vif = calculate_vif(features1)
vif
# Out:
#                      Features            VIF
# 0         Segment_hibernating       2.547265
# 1          Order Quantity_max      73.700656
# 2               Tenure_months       6.973611
# 3     Number_children_at_home       1.980538
# 4                 RFM_cluster       7.086384
# 5         Order Quantity_mean     643.430105
# 6                 Profit_mean  640285.114875
# 7          Order Quantity_sum       6.506381
# 8                  Profit_max   96358.008624
# 9               Car_ownership       4.016797
# 10                 Profit_sum    2486.496968
# 11       Sales_reason_Quality      15.875108
# 12                Revenue_min   57159.304012
# 13              Profit_median   73864.506535
# 14                 Profit_min   54451.789608
# 15                Revenue_max  100029.565494
# 16                Revenue_sum    2598.771105
# 17             Revenue_median   80265.150815
# 18                        Age      11.152929
# 19  Sales_reason_Manufacturer      15.183934
# ...

# %%
# Narrow down the features until their VIF is equal to or lower than 5
while vif['VIF'][vif['VIF'] > 5].any():
    remove = vif.sort_values('VIF',ascending=0)['Features'][:1]
    features1.drop(remove,axis=1,inplace=True)
    vif = calculate_vif(features1)

vif
# Out:
#                   Features       VIF
# 0      Segment_hibernating  2.261048
# 1            Tenure_months  3.237325
# 2  Number_children_at_home  1.740868
# 3              RFM_cluster  3.875734
# 4       Order Quantity_sum  2.718856
# 5            Car_ownership  2.929273
# 6     Sales_reason_Quality  1.903107
# 7              Revenue_min  2.338402

# %%
final_features = vif['Features']

# %%
# Create the final dataframe with all selected features and label
final_var = list(vif['Features']) + ['Churn'] #+ ['Segment_hibernating', 'Segment_new customers'] - #+['RFM_cluster']
final_df = encoded_data[final_var]
final_df.head()
# Out:
#    Segment_hibernating  Tenure_months  Number_children_at_home  RFM_cluster  \
# 0                    0      12.222017                        0            0
# 1                    0       0.000000                        0            1
# 2                    0       7.326639                        0            1
# 3                    0       0.000000                        0            1
# 4                    0       0.000000                        0            1
#
#    Order Quantity_sum  Car_ownership  Sales_reason_Quality  Revenue_min  Churn
# 0                 3.0              0                     0    2071.4196      0
# 1                 3.0              0                     0     614.4700      0
# 2                 3.0              1                     0      34.9900      0
# 3                 4.0              1                     0      73.9600      0
# 4                 2.0              1                     0      78.9800      0

# %%
# Final check for correlation between variables
corr = final_df.corr()
corr
# Out:
#                          Segment_hibernating  Tenure_months  \
# Segment_hibernating                 1.000000      -0.488302
# Tenure_months                      -0.488302       1.000000
# Number_children_at_home            -0.042285       0.002980
# RFM_cluster                         0.467047      -0.640865
# Order Quantity_sum                 -0.302461       0.349251
# Car_ownership                      -0.006877      -0.034539
# Sales_reason_Quality               -0.143091       0.534785
# Revenue_min                        -0.071682       0.361637
# Churn                               0.675960      -0.184625
#
#                          Number_children_at_home  RFM_cluster  \
# Segment_hibernating                    -0.042285     0.467047
# Tenure_months                           0.002980    -0.640865
# Number_children_at_home                 1.000000    -0.032426
# RFM_cluster                            -0.032426     1.000000
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
cor = final_df#.loc[:, final_df.columns != 'Churn']
cor = cor.corr()
ax=sns.heatmap(cor,annot=True,cmap=plt.cm.CMRmap_r)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Extra - Chi2 dependancy check

# %% [markdown]
# An extra measure to check for dependancy between correlated features was conduncted using Chi squared test. In this case he two example features used was the "Sales_reason_Quality" and "Sales_reason_Manufacturer"

# %%
sales_reason_crosstab = pd.crosstab(feature_df['Sales_reason_Manufacturer'], feature_df['Sales_reason_Quality'],
                                      margins=True)
sales_reason_crosstab
# Out:
# Sales_reason_Quality          0     1    All
# Sales_reason_Manufacturer
# 0                          9554     0   9554
# 1                            83  1063   1146
# All                        9637  1063  10700

# %%
from scipy import stats
from sklearn.feature_selection import SelectKBest, chi2
def check_categorical_dependency(crosstab_table, confidence_interval):
    stat, p, dof, expected = stats.chi2_contingency(crosstab_table)
    print ("Chi-Square Statistic value = {}".format(stat))
    print ("P - Value = {}".format(p))
    alpha = 1.0 - confidence_interval
    if p <= alpha:
        print('Dependent (reject H0)')
    else:
	      print('Independent (fail to reject H0)')
    return expected

# %%
exp_table_1 = check_categorical_dependency(sales_reason_crosstab, 0.95)
# Out:
# Chi-Square Statistic value = 9839.562814276926
# P - Value = 0.0
# Dependent (reject H0)

# %%
# proves that both variables are highly correlaed and dependant with each other.

# %% [markdown]
# ## Model Selection

# %% [markdown]
# ### Test/Training Set

# %%
encoded_data.columns
# Out:
# Index(['Order Quantity_sum', 'Order Quantity_mean', 'Order Quantity_median',
#        'Order Quantity_max', 'Revenue_sum', 'Revenue_mean', 'Revenue_median',
#        'Revenue_min', 'Revenue_max', 'Profit_sum', 'Profit_mean',
#        'Profit_median', 'Profit_min', 'Profit_max', 'RFM_cluster',
#        'Tenure_months', 'Churn', 'Yearly_income', 'Total_children',
#        'Number_children_at_home', 'House_ownership', 'Car_ownership', 'Age',
#        'Sales_reason_type_Marketing', 'Sales_reason_type_Other',
#        'Sales_reason_type_Promotion', 'Sales_reason_Manufacturer',
#        'Sales_reason_On Promotion', 'Sales_reason_Other', 'Sales_reason_Price',
#        'Sales_reason_Quality', 'Sales_reason_Review',
#        'Sales_reason_Television  Advertisement', 'Education_Bachelors',
#        'Education_Graduate Degree', 'Education_High School',
#        'Education_Partial College', 'Education_Partial High School',
# ...

# %%
final_df.head()
# Out:
#    Segment_hibernating  Tenure_months  Number_children_at_home  RFM_cluster  \
# 0                    0      12.222017                        0            0
# 1                    0       0.000000                        0            1
# 2                    0       7.326639                        0            1
# 3                    0       0.000000                        0            1
# 4                    0       0.000000                        0            1
#
#    Order Quantity_sum  Car_ownership  Sales_reason_Quality  Revenue_min  Churn
# 0                 3.0              0                     0    2071.4196      0
# 1                 3.0              0                     0     614.4700      0
# 2                 3.0              1                     0      34.9900      0
# 3                 4.0              1                     0      73.9600      0
# 4                 2.0              1                     0      78.9800      0

# %%
# Split dataset into train/test
X = final_df.loc[:, final_df.columns != 'Churn']
y = final_df['Churn']
test_pct = 0.3
# No need to add stratify parameter - the dataset is balanced
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = test_pct, random_state = seed)

print(len(X_train), len(y_train))
# Out:
# 7490 7490

# %%
model2 = GradientBoostingClassifier(n_estimators=10)
viz2 = FeatureImportances(model2, topn=8, relative=False)
viz2.fit(X, y)
viz.show()

# %%
viz2.features_
# Out:
# array(['Number_children_at_home', 'Car_ownership', 'Order Quantity_sum',
#        'Revenue_min', 'RFM_cluster', 'Sales_reason_Quality',
#        'Tenure_months', 'Segment_hibernating'], dtype=object)

# %%
# # Split dataset into train/test
# X = final_df[viz2.features_]
# y = final_df['Churn']
# test_pct = 0.3
# # No need to add stratify parameter - the dataset is balanced
# X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = test_pct, random_state = seed)

# print(len(X_train), len(y_train))

# %% [markdown]
# ### Model Algorithms

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB # Naive Bayes
from sklearn.svm import SVC

from sklearn import model_selection

# prepare configuration for cross validation test harness
# random seed to allow us to recreate results
# the number is a memoery location in the CPU

# prepare models
models = [] # an empty list
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis())) # LDA for short
models.append(('GB', GradientBoostingClassifier()))
models.append(('KNN', KNeighborsClassifier())) # KNN
models.append(('CART', DecisionTreeClassifier()))
models.append(('RF', RandomForestClassifier()))
models.append(('ETC',ExtraTreesClassifier()))
models.append(('NB', GaussianNB())) # Naive Bayes
models.append(('SVM', SVC()))
models.append(('NN',MLPClassifier()))


# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
print("Accuracy Scores% (+Std%): \n")
for name, model in models:
    # K Folds used - a more robust way to split our data into training/test
    kfold = model_selection.StratifiedKFold(n_splits=10, random_state=seed)
    cv_results = model_selection.cross_val_score(model, X, y, cv=kfold, scoring=scoring)

    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)

# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm "accuracy" Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# Accuracy Scores% (+Std%):
#
# LR: 0.842150 (0.073894)
# LDA: 0.848037 (0.065602)
# GB: 0.858318 (0.070576)
# KNN: 0.737570 (0.077733)
# CART: 0.811869 (0.063580)
# RF: 0.835607 (0.081035)
# ETC: 0.826636 (0.072011)
# NB: 0.837944 (0.094112)
# SVM: 0.477477 (0.034606)
# NN: 0.828598 (0.094080)

# %%
# prepare models
models = [] # an empty list
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis())) # LDA for short
models.append(('GB', GradientBoostingClassifier()))
models.append(('KNN', KNeighborsClassifier())) # KNN
models.append(('CART', DecisionTreeClassifier()))
models.append(('RF', RandomForestClassifier()))
models.append(('ETC',ExtraTreesClassifier()))
models.append(('NB', GaussianNB())) # Naive Bayes
models.append(('SVM', SVC()))
models.append(('NN',MLPClassifier()))


# evaluate each model in turn
results = []
names = []
scoring = 'f1'
print("F1 Scores% (+Std%): \n")
for name, model in models:
    # K Folds used - a more robust way to split our data into training/test
    kfold = model_selection.StratifiedKFold(n_splits=10, random_state=seed)
    cv_results = model_selection.cross_val_score(model, X, y, cv=kfold, scoring=scoring)

    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)

# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm "f1" Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# F1 Scores% (+Std%):
#
# LR: 0.833458 (0.094686)
# LDA: 0.845585 (0.078916)
# GB: 0.854083 (0.086790)
# KNN: 0.729164 (0.109598)
# CART: 0.801244 (0.085083)
# RF: 0.826203 (0.111483)
# ETC: 0.820071 (0.087475)
# NB: 0.818556 (0.126923)
# SVM: 0.444462 (0.222791)
# NN: 0.764673 (0.158136)

# %%
# Scale data
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
scaler.fit(X_test)
X_test_scaled = scaler.transform(X_test)

# %%
lda = LinearDiscriminantAnalysis()
lda1 = LinearDiscriminantAnalysis(solver='lsqr', shrinkage= 'auto')
lda2= LinearDiscriminantAnalysis(solver='eigen', shrinkage= 'auto')
# Use scaled data
lda.fit(X_train_scaled, y_train)

train_pred = lda.predict(X_train_scaled)
test_pred = lda.predict(X_test_scaled)

train_acc = 100*lda.score(X_train_scaled, y_train)
test_acc = 100*lda.score(X_test_scaled, y_test)
train_f1 = 100*fbeta_score(y_train, train_pred, beta = 1)
test_f1 = 100*fbeta_score(y_test, test_pred, beta = 1)

scores = np.array([train_acc, test_acc, train_f1, test_f1])
metrics = ['train_accuracy', 'test_accuracy', 'train_f1_score', 'test_f1_score']
# Create the dataframe
pd.options.display.float_format = '{:.2f}'.format
LDA_df = pd.DataFrame(scores, columns = ['LDA'], index = metrics).reset_index()
LDA_df
# Out:
#             index   LDA
# 0  train_accuracy 84.45
# 1   test_accuracy 85.23
# 2  train_f1_score 84.70
# 3   test_f1_score 85.62

# %% [markdown]
# ### Hyperparameter Tuning

# %% [markdown]
# #### Validation curves

# %%
# Plot validation curve for various parameters to estimate their optimal values
# This will help us narrow down the potential values and therefore reduce running time of Grid search
# Check out current parametrers
print(lda.get_params())
# Out:
# {'n_components': None, 'priors': None, 'shrinkage': None, 'solver': 'svd', 'store_covariance': False, 'tol': 0.0001}

# %%
from numpy import arange
# n_estimators parameter
# Create a list with the range of values for n_estimators
shrinkage = [float(x) for x in arange(0.0,1.0,0.1)]
# Obtain train and test scores from validation curve
# Use all data for cross validation - no need to split into train and test sets
train_scores, test_scores = validation_curve(lda1, X, y,
                                             param_name = "shrinkage",
                                             param_range = shrinkage,
                                             cv = kfold, scoring= "f1",
                                             n_jobs= -1)
train_scores2, test_scores2 = validation_curve(lda2, X, y,
                                             param_name = "shrinkage",
                                             param_range = shrinkage,
                                             cv = kfold, scoring= "f1",
                                             n_jobs= -1)

# %%
def validation_curve_plot(parameter, values, train_scores, test_scores):
    '''Calculate mean and standard deviation for training set scores'''
    train_mean = np.mean(train_scores, axis = 1)
    train_std = np.std(train_scores, axis = 1)

    '''Calculate mean and standard deviation for test set scores'''
    test_mean = np.mean(test_scores, axis = 1)
    test_std = np.std(test_scores, axis = 1)

    '''Plot mean accuracy scores for training and test sets'''
    plt.plot(values, train_mean, label="Training score", color="black")
    plt.plot(values, test_mean, label="Cross-validation score", color="dimgrey")

    '''Plot accurancy bands for training and test sets'''
    plt.fill_between(values, train_mean - train_std, train_mean + train_std, color="gray")
    plt.fill_between(values, test_mean - test_std, test_mean + test_std, color="gainsboro")

    '''Create plot'''
    plt.xlabel(parameter)
    plt.ylabel("F1 score")
    plt.tight_layout()
    plt.legend(loc="best")

# Call function to plot validation curve
validation_curve_plot("shrinkage", shrinkage, train_scores, test_scores)

# %% [markdown]
# #### Grid Search Cross Validation

# %%
# define model
model = LinearDiscriminantAnalysis(solver='lsqr')
# define model evaluation method
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# define grid
grid = dict()
grid['shrinkage'] = arange(0, 1, 0.01)
# define search
search = GridSearchCV(model, grid, scoring='accuracy', cv=cv, n_jobs=-1)
# perform the search
results = search.fit(X, y)
# summarize
print('Mean Accuracy: %.3f' % results.best_score_)
print('Config: %s' % results.best_params_)
# Out:
# Mean Accuracy: 0.847
# Config: {'shrinkage': 0.0}

# %%
from sklearn.model_selection import RepeatedStratifiedKFold

# define model
model = LinearDiscriminantAnalysis()
# define model evaluation method
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=seed)
# define grid
grid = dict()
grid['solver'] = ['svd', 'lsqr', 'eigen']
# define search
search = GridSearchCV(model, grid, scoring='accuracy', cv=cv, n_jobs=-1)
# perform the search
results = search.fit(X, y)
# summarize
print('Mean Accuracy: %.3f' % results.best_score_)
print('Config: %s' % results.best_params_)
# Out:
# Mean Accuracy: 0.847
# Config: {'solver': 'svd'}

# %%
search = GridSearchCV(model, grid, scoring='f1', cv=cv, n_jobs=-1)
# perform the search
results = search.fit(X, y)
# summarize
print('Mean F1 Score: %.3f' % results.best_score_)
print('Config: %s' % results.best_params_)
# Out:
# Mean F1 Score: 0.850
# Config: {'solver': 'svd'}

# %%
print(results.best_estimator_ )
best = results.best_estimator_
print(best.get_params())
# Out:
# LinearDiscriminantAnalysis()
# {'n_components': None, 'priors': None, 'shrinkage': None, 'solver': 'svd', 'store_covariance': False, 'tol': 0.0001}

# %% [markdown]
# ## Evaluating the Model

# %% [markdown]
# ### Classification Report

# %%
# Print the score of the best estimator
best_score = results.best_score_ * 100
print("Best mean f1 test score: {:.2f}%".format(best_score))
# Out:
# Best mean f1 test score: 85.01%

# %%
# a near negligible improvement of about 0.04%. Meaning that the the default settings of LDA were already the optimial
# settings for the algorithm

# %%
# Make predictions
y_pred = results.best_estimator_.predict(X)
# Print classification report
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.84      5189
#            1       0.86      0.84      0.85      5511
#
#     accuracy                           0.85     10700
#    macro avg       0.85      0.85      0.85     10700
# weighted avg       0.85      0.85      0.85     10700

# %%
#Functions for Supervised Classification Performance Metrics

def plot_roc_curve(y_true, y_score):
    from sklearn.metrics import roc_curve, auc

    fpr, tpr, _ = roc_curve(y_true=y_true, y_score=y_score)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(9, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC (auc = {:0.2})'.format(roc_auc))
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")

def plot_confusion_matrix(cm, class_names):
    import itertools

    cm = cm.astype(np.float)# / cm.sum(axis=1)[:, np.newaxis] # commented out to ensure we
    # have absolute numbers in confusion matrix

    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion matrix')
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45)
    plt.yticks(tick_marks, class_names)

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        color = "white" if cm[i, j] > cm.max() / 2 else "black"
        plt.text(j, i, format(cm[i, j], '.0f'), horizontalalignment="center", color=color)

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.rcParams["figure.figsize"] = (7,7)
    plt.grid(b=None)

    plt.show()

# %%
# Exercise - confusion matrix
plot_confusion_matrix(confusion_matrix(y, y_pred),["No Churn", "Churn"])

# %%
y_score = results.best_estimator_.predict_proba(X)[:,1]
y_score
# Out:
# array([0.15877736, 0.04689428, 0.03010015, ..., 0.8046514 , 0.98030575,
#        0.98030575])

# %%
# Exercise - ROC Curve
plot_roc_curve(y,y_score)

# %% [markdown]
# so AUC (area under the curve) = 0.89 - a very good model

# %%
# Save model
final_model = results.best_estimator_
filename = 'final_churning_model'
joblib.dump(final_model, filename)
# Out:
# ['final_churning_model']

# %% [markdown]
# ## A/B testing

# %% [markdown]
# Null Hypothesis (Ho) - Targeting predicted chuners with a marketing campaign will maximise profits more than targeting all customers

# %%
tn, fp, fn, tp = confusion_matrix(y, y_pred).ravel()

# %%
# Calculate average revenue per customer for a year
# Find latest date of sales data
max(Transactions['Order Date'])
# Out:
# Timestamp('2014-01-28 00:00:00')

# %%
# Find earliest date of sales data
min(Transactions['Order Date'])
# Out:
# Timestamp('2010-12-29 00:00:00')

# %%
# Summarise sales by Order Date
daily_sales = Transactions.groupby('Order Date').agg({'Revenue':'sum'})
daily_sales.head()
# Out:
#             Revenue
# Order Date
# 2010-12-29 14477.34
# 2010-12-30 13931.52
# 2010-12-31 15012.18
# 2011-01-01  7156.54
# 2011-01-02 15012.18

# %%
# Summarise data by monthly sales
monthly_sales = daily_sales.resample('MS').sum()
monthly_sales.head()
# Out:
#              Revenue
# Order Date
# 2010-12-01  43421.04
# 2011-01-01 469823.91
# 2011-02-01 466334.90
# 2011-03-01 485198.66
# 2011-04-01 502073.85

# %%
# Plot data
ax = monthly_sales['Revenue'].plot(figsize=(15, 6), color = 'mediumslateblue')
ax.xaxis.set_label_text("")
ax.set_ylim(ymin=0)
pass

# %%
# Calculate revenue per customer for each of the 3 full years
data = Transactions.set_index('Order Date')
df1 = data['2011-01-01' : '2011-12-31']
df2 = data['2012-01-01' : '2012-12-31']
df3 = data['2013-01-01' : '2013-12-31']
df_list = [df1, df2, df3]

rev_list = []
for df in df_list:
    rev = sum(df.Revenue)
    customer_num = len(df['Customer_ID'].unique())
    customer_rev = rev / customer_num
    rev_list.append(customer_rev)

# Calculate average annual revenue per customer
annual_customer_rev = sum(rev_list)/len(rev_list)
annual_customer_rev
# Out:
# 1975.3446095266863

# %%
# Let's assume there is a cost per customer
# E.g. a voucher to entice customers could be considered mitigation cost
mitigation_cost = 350
# Alternatively we could set cost to be 5% of the average annual customer revenue
# mitigation_cost = annual_customer_rev * 0.05

# %%
# Calculate profit for baseline and model scenarios
baseline_spend = mitigation_cost * (tp + tn + fp + fn)
baseline_rev = annual_customer_rev * (tp + fn)
baseline_profit = baseline_rev - baseline_spend

model_spend = mitigation_cost * (tp + fp)
model_rev = annual_customer_rev * tp
model_profit = model_rev - model_spend

print('If we targeted all customers with an effective mitigation strategy, the profit would be', int(baseline_profit))
print('If we targeted only the predicted churners with an effective mitigation strategy, the profit would be',int(model_profit))
print('This is an improvement of {:0.2f}%'.format((model_profit-baseline_profit)/baseline_profit*100))
# Out:
# If we targeted all customers with an effective mitigation strategy, the profit would be 7141124
# If we targeted only the predicted churners with an effective mitigation strategy, the profit would be 7269097
# This is an improvement of 1.79%

# %%
# If we are unsure about mitigation cost, we can determine the best strategy by trying various values
baseline_profit = []
model_profit =[]

for i in range(400):
    baseline_profit.append(baseline_rev - (tp+fp+tn+fn) * i)
    model_profit.append(model_rev - (tp+fp) * i)


fig = plt.figure()
ax = plt.axes()

x = range(400)
y1 = baseline_profit
y2 = model_profit
ax.plot(x,y1,color='chartreuse', label ='Baseline')
ax.plot(x,y2,color='fuchsia', label ='Model')
ax.legend()
plt.xlabel('Mitigation cost')
plt.ylabel('Profit')
pass

# %%
y1 = np.array(y1)
y2 = np.array(y2)
idx = np.argwhere(np.diff(np.sign(y1 - y2))).flatten()
int(idx)
# Out:
# 325

# %%
print('Our model is superior to the baseline scenario when the mitigation cost exceeds',int(idx),'dollars per customer')
# Out:
# Our model is superior to the baseline scenario when the mitigation cost exceeds 325 dollars per customer

# %% [markdown]
# ### Maximum Return

# %%
# Goal: Maximum return on investment; our metric in this case is precision
# Calculate baseline and model return
baseline_return = (baseline_rev - baseline_spend) / baseline_spend *100
model_return = (model_rev - model_spend) / model_spend *100

# %%
print('If we targeted all customers with an effective mitigation strategy, the return on investment would be {:0.2f}%'.format(baseline_return))
print('If we targeted only the predicted churners with an effective mitigation strategy, the return on investment would be {:0.2f}%'.format(model_return))
# Out:
# If we targeted all customers with an effective mitigation strategy, the return on investment would be 190.68%
# If we targeted only the predicted churners with an effective mitigation strategy, the return on investment would be 384.89%

# %%
# If we are unsure about mitigation cost, we can determine the best strategy by trying various values
baseline_return = []
model_return =[]

for i in range(1,400):
    baseline_return.append((baseline_rev - (tp+fp+tn+fn) * i)/ ((tp+fp+tn+fn) * i) * 100)
    model_return.append((model_rev - (tp+fp) * i)/ ((tp+fp) * i) * 100)

fig = plt.figure()
ax = plt.axes()

x = range(1,400)
y1 = baseline_return
y2 = model_return
ax.plot(x,y1,color='chartreuse', label ='Baseline')
ax.plot(x,y2,color='fuchsia', label ='Model')
ax.legend()
plt.xlabel('Mitigation cost')
plt.ylabel('Return %')
pass

# %%
print('Our model would give better return on investment compared to the baseline scenario regardless of the mitigation cost')
# Out:
# Our model would give better return on investment compared to the baseline scenario regardless of the mitigation cost

# %% [markdown]
# ## Data Scoring

# %% [markdown]
# ### Data preparation

# %%
score_data.head().transpose()
# Out:
#                                                       6393   \
# Customer_ID                                           17393
# Order Quantity_sum                                     4.00
# Order Quantity_mean                                    4.00
# Order Quantity_median                                  4.00
# Order Quantity_min                                     4.00
# Order Quantity_max                                     4.00
# Revenue_sum                                         2404.91
# Revenue_mean                                        2404.91
# Revenue_median                                      2404.91
# Revenue_min                                         2404.91
# Revenue_max                                         2404.91
# Profit_sum                                          1107.53
# Profit_mean                                         1107.53
# Profit_median                                       1107.53
# Profit_min                                          1107.53
# ...

# %%
score_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7784 entries, 6393 to 10080
# Data columns (total 54 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Customer_ID                             7784 non-null   int64
#  1   Order Quantity_sum                      7784 non-null   float64
#  2   Order Quantity_mean                     7784 non-null   float64
#  3   Order Quantity_median                   7784 non-null   float64
#  4   Order Quantity_min                      7784 non-null   float64
#  5   Order Quantity_max                      7784 non-null   float64
#  6   Revenue_sum                             7784 non-null   float64
#  7   Revenue_mean                            7784 non-null   float64
#  8   Revenue_median                          7784 non-null   float64
#  9   Revenue_min                             7784 non-null   float64
# ...

# %%
# Double check for missing values and duplicates
score_data.isnull().sum()[score_data.isnull().sum()!=0]
# Out:
# Days Elapsed_mean      4491
# Days Elapsed_median    4491
# Days Elapsed_min       4491
# Days Elapsed_max       4491
# dtype: int64

# %%
# Check for potential duplicate rows
print('Number of duplicates:', score_data.duplicated().sum())
# Out:
# Number of duplicates: 0

# %%
# Delete fields that are of no use for our modelling
# Exclude Customer_id from deleted list so we can idetify churning customers later on
deleted.remove('Customer_ID')
deleted = deleted + ['Churn']
score_data.drop(deleted, axis = 1, inplace= True)

# %%
# Get distribution/frequency per category
for var in cat:
 print(score_data[var].value_counts())
# Out:
# 1    5739
# 0    2025
# 2      20
# Name: RFM_cluster, dtype: int64
# M    4218
# S    3566
# Name: Marital_status, dtype: int64
# M    3928
# F    3856
# Name: Gender, dtype: int64
# loyal customers    1846
# new customers      1277
# about to sleep     1265
# promising          1231
# champions          1008
# hibernating         718
# at risk             372
# can't loose          67
# Name: Segment, dtype: int64
# 1    5259
# 0    2525
# Name: House_ownership, dtype: int64
# 0    4640
# 1    1015
# 2     705
# 4     506
# 3     501
# 5     417
# Name: Number_children_at_home, dtype: int64
# 2    2668
# 1    2056
# 0    1778
# 3     718
# 4     564
# Name: Car_ownership, dtype: int64
# 0    2193
# 2    1596
# 1    1474
# 4     985
# 3     933
# 5     603
# Name: Total_children, dtype: int64
# Bachelors              2303
# Partial College        2135
# High School            1381
# Graduate Degree        1313
# Partial High School     652
# Name: Education, dtype: int64
# ...

# %%
# PLot distribution/frequency per category
cat_df = score_data[cat]
plt.rcParams['figure.figsize'] = (15, 5) # Chart sizes

for i, col in enumerate(cat_df.columns):
   plt.figure(i)
   sns.countplot(x=col, data=cat_df, color = 'mediumslateblue')

# %%
# PLot distribution/frequency per category
cat_df = score_data[cat]
plt.rcParams['figure.figsize'] = (15, 5) # Chart sizes

for i, col in enumerate(cat_df.columns):
   plt.figure(i)
   sns.countplot(x=col, data=cat_df, color = 'mediumslateblue')

# %%
# Encode categorical data (besides drivers which are already binary)
encoded_score_data = pd.get_dummies(score_data, columns = [v for v in dummies], drop_first = False)

# %%
encoded_score_var = list(encoded_score_data.columns)
encoded_score_var
# Out:
# ['Customer_ID',
#  'Order Quantity_sum',
#  'Order Quantity_mean',
#  'Order Quantity_median',
#  'Order Quantity_max',
#  'Revenue_sum',
#  'Revenue_mean',
#  'Revenue_median',
#  'Revenue_min',
#  'Revenue_max',
#  'Profit_sum',
#  'Profit_mean',
#  'Profit_median',
#  'Profit_min',
#  'Profit_max',
#  'RFM_cluster',
#  'Tenure_months',
#  'Marital_status',
#  'Gender',
#  'Yearly_income',
#  'Total_children',
#  'Number_children_at_home',
#  'House_ownership',
#  'Car_ownership',
#  'Age',
#  'Sales_reason_type_Marketing',
#  'Sales_reason_type_Other',
#  'Sales_reason_type_Promotion',
#  'Sales_reason_Manufacturer',
#  'Sales_reason_On Promotion',
#  'Sales_reason_Other',
#  'Sales_reason_Price',
#  'Sales_reason_Quality',
#  'Sales_reason_Review',
#  'Sales_reason_Television  Advertisement',
#  'Education_Bachelors',
#  'Education_Graduate Degree',
#  'Education_High School',
#  'Education_Partial College',
#  'Education_Partial High School',
#  'Occupation_Clerical',
# ...

# %%
# Filter continuous variables
cont = [v for v in cols if v not in cat and v not in deleted and v != 'Customer_ID']

# %%
# Get quick stats
encoded_score_data[cont].describe().transpose()
# Out:
#                         count     mean      std      min      25%      50%  \
# Order Quantity_sum    7784.00     3.50     2.85     1.00     2.00     3.00
# Order Quantity_mean   7784.00     2.27     0.90     1.00     1.67     2.00
# Order Quantity_median 7784.00     2.26     0.92     1.00     1.50     2.00
# Order Quantity_max    7784.00     2.64     1.09     1.00     2.00     3.00
# Revenue_sum           7784.00  1621.15  2210.77     2.29    53.98   223.31
# Revenue_mean          7784.00   864.34   984.95     2.29    39.98   129.97
# Revenue_median        7784.00   862.48   983.52     2.29    39.98   131.44
# Revenue_min           7784.00   707.24   848.84     2.29    36.27   128.97
# Revenue_max           7784.00  1024.11  1200.47     2.29    45.95   154.96
# Profit_sum            7784.00   671.22   914.45     1.43    28.31   130.64
# Profit_mean           7784.00   356.44   403.60     1.43    24.40    74.88
# ...

# %%
# Plot boxplots
encoded_score_data[cont].plot(kind='box', subplots=True, figsize=(20,40),
                      layout=(9,4), sharex=False, sharey=False)
plt.show()

# %%
# PLot histograms
encoded_score_data[cont].hist(figsize=(20,40), color = 'mediumslateblue')
pass

# %%
# Check if all encoded features of model dataset are included in score dataset
result = all(v in encoded_score_var for v in final_features)
if result:
    print('All encoded features of model dataset are included in score dataset.')
else:
    print('Not all encoded features of model dataset are included in score dataset.')
# Out:
# All encoded features of model dataset are included in score dataset.

# %%
# Find which encoded features are not present in score dataset
missing_var = set(final_features) - set(encoded_score_var)
missing_var
# Out:
# set()

# %%
# Create missing fields and assign 0 to all rows
for v in missing_var:
    encoded_score_data[v] = 0

# %%
# Create the final score dataframe with all selected features and Customer id
score_df = encoded_score_data[final_features]
score_df.insert(0, 'Customer_ID', encoded_score_data['Customer_ID'])
score_df.head()
# Out:
#        Customer_ID  Segment_hibernating  Tenure_months  \
# 6393         17393                    0           0.00
# 3767         14767                    0           0.00
# 14352        25352                    0           0.00
# 10617        21617                    0           0.00
# 6558         17558                    0           0.00
#
#        Number_children_at_home  RFM_cluster  Order Quantity_sum  \
# 6393                         2            1                4.00
# 3767                         1            1                2.00
# 14352                        1            1                2.00
# 10617                        0            1                2.00
# 6558                         0            1                3.00
#
#        Car_ownership  Sales_reason_Quality  Revenue_min
# 6393               4                     0      2404.91
# 3767               0                     0        29.93
# 14352              2                     0        29.98
# ...

# %% [markdown]
# ### Model Deployment

# %%
loaded_model = joblib.load('final_churning_model')
loaded_model
# Out:
# LinearDiscriminantAnalysis()

# %%
loaded_model2=GradientBoostingClassifier(criterion='friedman_mse', init=None,
                           learning_rate=0.1, loss='deviance', max_depth=3,
                           max_features='auto', max_leaf_nodes=None,
                           min_impurity_decrease=0.0, min_impurity_split=None,
                           min_samples_leaf=5, min_samples_split=2,
                           min_weight_fraction_leaf=0.0, n_estimators=100,
                           n_iter_no_change=None, presort='auto',
                           random_state=53, subsample=1.0, tol=0.0001,
                           validation_fraction=0.1, verbose=0,
                           warm_start=False)

# %%
# Make predictions
features = score_df.loc[:, score_df.columns != 'Customer_ID']
loaded_model2.fit(X,y)
predictions = loaded_model.predict(features)
# Add a new column to the dataframe with the predictions
score_df.insert(1, "Churn", predictions, True)
score_df.head()
# Out:
#        Customer_ID  Churn  Segment_hibernating  Tenure_months  \
# 6393         17393      0                    0           0.00
# 3767         14767      0                    0           0.00
# 14352        25352      0                    0           0.00
# 10617        21617      0                    0           0.00
# 6558         17558      0                    0           0.00
#
#        Number_children_at_home  RFM_cluster  Order Quantity_sum  \
# 6393                         2            1                4.00
# 3767                         1            1                2.00
# 14352                        1            1                2.00
# 10617                        0            1                2.00
# 6558                         0            1                3.00
#
#        Car_ownership  Sales_reason_Quality  Revenue_min
# 6393               4                     0      2404.91
# 3767               0                     0        29.93
# ...

# %%
# Show how many customers are predicted to churn (1) and not to churn (0)
score_df.groupby('Churn').size()
# Out:
# Churn
# 0    6598
# 1    1186
# dtype: int64

# %%
# Filter potential churners
predicted_churners = score_df[score_df['Churn'] == 1]

# %%
# Export the dataframe to a csv file
filename = 'Predicted churners.csv'
csv_file = predicted_churners.to_csv(filename, index = None, header = True)

# %%
# Estimate commercial value if our strategy is successful in preventing churning
int(annual_customer_rev * len(predicted_churners))
# Out:
# 2342758

# %% [markdown]
# ## Customer Profiling

# %%
# Plot boxplots by Churn
plt.rcParams['figure.figsize'] = (7, 5)
cont_df = single_view[cont]
for i, col in enumerate(cont_df .columns):
   plt.figure(i)
   sns.boxplot(data = cont_df, y = col , x = single_view['Churn'])

# %%
# Plot distribution by Churn of select categorical variables as a proportion
select_var = ["RFM_cluster", "Sales_reason_Price", 'Marital_status', 'Gender',"Income_group","Number_children_at_home",
              "Car_ownership",'Education', 'Occupation',"House_ownership",'Total_children']
y = "%"
hue = 'Churn'
plt.rcParams['figure.figsize'] = (9, 5)
for i, v in enumerate(select_var):
    #plt.figure(figsize=(8, 8))
    plt.figure(i)
    prop_df = (single_view[v]
               .groupby(single_view[hue])
               .value_counts(normalize=True)
               .mul(100)
               .rename(y)
               .reset_index())

    sns.barplot(x=v, y=y, hue=hue, data=prop_df)
    plt.yticks(fontsize=13)
    plt.xticks(fontsize=13);

# %%
# Plot distribution by Churn of select categorical variables as a proportion
select_var = ["RFM_cluster", "Sales_reason_Price", 'Marital_status', 'Gender',"Income_group","Number_children_at_home",
              "Car_ownership",'Education', 'Occupation',"House_ownership",'Total_children']
y = "Revenue_mean"
hue = 'Churn'
plt.rcParams['figure.figsize'] = (9, 5)
cont_df = single_view
for i, v in enumerate(select_var):
    plt.figure(i)
    sns.barplot(x=v, y=y, hue=hue, data=cont_df,ci=None)
    plt.yticks(fontsize=13)
    plt.xticks(fontsize=13);

# %%
single_view.columns
# Out:
# Index(['Customer_ID', 'Order Quantity_sum', 'Order Quantity_mean',
#        'Order Quantity_median', 'Order Quantity_min', 'Order Quantity_max',
#        'Revenue_sum', 'Revenue_mean', 'Revenue_median', 'Revenue_min',
#        'Revenue_max', 'Profit_sum', 'Profit_mean', 'Profit_median',
#        'Profit_min', 'Profit_max', 'Days Elapsed_sum', 'Days Elapsed_mean',
#        'Days Elapsed_median', 'Days Elapsed_min', 'Days Elapsed_max',
#        'Frequency', 'Monetary', 'Recency', 'RFM Score', 'Segment',
#        'RFM_cluster', 'Tenure_months', 'Days since first Transaction', 'Churn',
#        'Birth_date', 'Marital_status', 'Gender', 'Yearly_income',
#        'Total_children', 'Number_children_at_home', 'Education', 'Occupation',
#        'House_ownership', 'Car_ownership', 'Commute_distance', 'Age',
#        'Age_group', 'Income_group', 'Sales_reason_type_Marketing',
#        'Sales_reason_type_Other', 'Sales_reason_type_Promotion',
# ...
